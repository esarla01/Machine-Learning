# %% [markdown]
# # Enhanced Sentiment Analysis (Project B)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd

import sklearn.linear_model
import sklearn.pipeline
from sklearn.utils import shuffle

# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# ### Load Training Data

# %%
import numpy as np
import pandas as pd
import os

data_dir = 'data_reviews'
x_train_df = pd.read_csv(os.path.join(data_dir, 'x_train.csv'))
y_train_df = pd.read_csv(os.path.join(data_dir, 'y_train.csv'))
x_test_df = pd.read_csv(os.path.join(data_dir, 'x_test.csv'))
our_test_x_df = pd.read_csv(os.path.join(data_dir, 'our_test_x.csv'))
our_test_y_df = pd.read_csv(os.path.join(data_dir, 'our_test_y.csv'))

# %% [markdown]
# ### Changing text format (df to np)

# %%
text_col_arr =  x_train_df['text'].values
results_col_arr = np.ravel(y_train_df.values)

# %% [markdown]
# ### Building a Custom Preprocessor

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Prepare a custom preprocessor to remove numbers
def custom_preprocessor(text):
  words = text.split()
  cleaned_words = []

  for word in words:
    cleaned_word = ''

    for char in word:
      if not char.isdigit():
        cleaned_word += char

    cleaned_words.append(cleaned_word)

  cleaned_text = " ". join(cleaned_words)
  return cleaned_text

def combined_preprocessor(text):
  text = CountVectorizer().build_preprocessor()(text)
  text = custom_preprocessor(text)
  return text

# %% [markdown]
# ### Bag-of-Words Extraction

# %%
# CountVectorizer configuration to analyze token frequencies
count_vectorizer = CountVectorizer(
    preprocessor=combined_preprocessor,
    min_df=5,  # Minimum document frequency
    max_df=0.1,  # Maximum document frequency
    ngram_range=(1, 1),  # N-gram range
)


# Fit and transform the text data using CountVectorizer
document_term_matrix = count_vectorizer.fit_transform(text_col_arr)

# Calculate the document frequency for each token
total_document_frequency = document_term_matrix.sum(axis=0)

# Convert the document frequency matrix to a list
document_frequency_list = total_document_frequency.tolist()[0]

# Create a dictionary mapping tokens to their document frequency
token_document_frequency_dict = dict(zip(count_vectorizer.get_feature_names_out(), document_frequency_list))

# Print the total number of tokens
total_tokens = len(token_document_frequency_dict)
print(f"Total Tokens: {total_tokens}")

# Print the document frequency for each token
for token, document_frequency in token_document_frequency_dict.items():
    print(f"Token: {token}, Document Frequency: {document_frequency}")
# Out:
# Total Tokens: 703
# Token: about, Document Frequency: 70
# Token: above, Document Frequency: 6
# Token: absolutely, Document Frequency: 18
# Token: acting, Document Frequency: 32
# Token: action, Document Frequency: 6
# Token: actor, Document Frequency: 7
# Token: actors, Document Frequency: 17
# Token: actually, Document Frequency: 14
# Token: after, Document Frequency: 40
# Token: again, Document Frequency: 40
# Token: ago, Document Frequency: 6
# Token: all, Document Frequency: 118
# Token: almost, Document Frequency: 14
# Token: also, Document Frequency: 57
# Token: although, Document Frequency: 8
# Token: always, Document Frequency: 16
# Token: am, Document Frequency: 27
# Token: amazing, Document Frequency: 29
# Token: amazon, Document Frequency: 6
# Token: amount, Document Frequency: 8
# Token: an, Document Frequency: 91
# Token: annoying, Document Frequency: 5
# Token: another, Document Frequency: 18
# Token: any, Document Frequency: 38
# Token: anyone, Document Frequency: 21
# Token: anything, Document Frequency: 13
# Token: anytime, Document Frequency: 5
# Token: are, Document Frequency: 143
# Token: area, Document Frequency: 7
# Token: around, Document Frequency: 19
# Token: arrived, Document Frequency: 7
# Token: art, Document Frequency: 11
# Token: as, Document Frequency: 136
# Token: ask, Document Frequency: 5
# Token: at, Document Frequency: 106
# Token: atmosphere, Document Frequency: 11
# Token: attentive, Document Frequency: 7
# Token: audio, Document Frequency: 7
# Token: authentic, Document Frequency: 6
# Token: average, Document Frequency: 5
# Token: avoid, Document Frequency: 10
# Token: away, Document Frequency: 12
# Token: awesome, Document Frequency: 16
# Token: awful, Document Frequency: 15
# Token: back, Document Frequency: 62
# Token: bad, Document Frequency: 81
# Token: bar, Document Frequency: 8
# Token: barely, Document Frequency: 11
# Token: bars, Document Frequency: 5
# Token: basically, Document Frequency: 5
# Token: battery, Document Frequency: 34
# Token: be, Document Frequency: 120
# Token: beautiful, Document Frequency: 14
# Token: because, Document Frequency: 47
# Token: beef, Document Frequency: 5
# Token: been, Document Frequency: 42
# Token: beer, Document Frequency: 5
# Token: before, Document Frequency: 15
# Token: being, Document Frequency: 29
# Token: believable, Document Frequency: 6
# Token: believe, Document Frequency: 9
# Token: belt, Document Frequency: 5
# Token: best, Document Frequency: 63
# Token: better, Document Frequency: 46
# Token: between, Document Frequency: 14
# Token: big, Document Frequency: 17
# Token: bit, Document Frequency: 11
# Token: black, Document Frequency: 14
# Token: bland, Document Frequency: 11
# Token: blue, Document Frequency: 6
# Token: bluetooth, Document Frequency: 13
# Token: boring, Document Frequency: 6
# Token: both, Document Frequency: 22
# Token: bother, Document Frequency: 5
# Token: bought, Document Frequency: 12
# Token: breakfast, Document Frequency: 9
# Token: brilliant, Document Frequency: 7
# Token: bring, Document Frequency: 5
# Token: broke, Document Frequency: 5
# Token: budget, Document Frequency: 6
# Token: buffet, Document Frequency: 10
# Token: burger, Document Frequency: 10
# Token: business, Document Frequency: 5
# Token: but, Document Frequency: 160
# Token: buttons, Document Frequency: 7
# Token: buy, Document Frequency: 15
# Token: buying, Document Frequency: 5
# Token: by, Document Frequency: 62
# Token: cable, Document Frequency: 7
# Token: call, Document Frequency: 12
# Token: calls, Document Frequency: 12
# Token: came, Document Frequency: 27
# Token: camera, Document Frequency: 17
# Token: can, Document Frequency: 70
# Token: cannot, Document Frequency: 8
# Token: car, Document Frequency: 15
# Token: care, Document Frequency: 9
# Token: case, Document Frequency: 30
# Token: cases, Document Frequency: 5
# Token: cast, Document Frequency: 15
# Token: casting, Document Frequency: 5
# Token: cell, Document Frequency: 11
# Token: certainly, Document Frequency: 9
# Token: character, Document Frequency: 17
# Token: characters, Document Frequency: 31
# Token: charge, Document Frequency: 13
# Token: charger, Document Frequency: 14
# Token: charging, Document Frequency: 5
# Token: charm, Document Frequency: 6
# Token: cheap, Document Frequency: 13
# Token: check, Document Frequency: 7
# Token: chicken, Document Frequency: 14
# Token: child, Document Frequency: 6
# Token: chips, Document Frequency: 5
# Token: cinema, Document Frequency: 7
# Token: cinematography, Document Frequency: 7
# Token: clean, Document Frequency: 8
# Token: clear, Document Frequency: 11
# Token: clever, Document Frequency: 5
# Token: close, Document Frequency: 7
# Token: cold, Document Frequency: 7
# Token: color, Document Frequency: 7
# Token: come, Document Frequency: 13
# Token: comes, Document Frequency: 7
# Token: comfortable, Document Frequency: 14
# Token: coming, Document Frequency: 12
# Token: company, Document Frequency: 6
# Token: completely, Document Frequency: 9
# Token: computer, Document Frequency: 5
# Token: considering, Document Frequency: 6
# Token: cooked, Document Frequency: 6
# Token: cool, Document Frequency: 17
# Token: could, Document Frequency: 42
# Token: couldn, Document Frequency: 13
# Token: couple, Document Frequency: 8
# Token: crap, Document Frequency: 9
# Token: customer, Document Frequency: 13
# Token: cute, Document Frequency: 5
# Token: damn, Document Frequency: 5
# Token: day, Document Frequency: 16
# Token: days, Document Frequency: 7
# Token: dead, Document Frequency: 6
# Token: deal, Document Frequency: 10
# Token: decent, Document Frequency: 6
# Token: definitely, Document Frequency: 27
# Token: delicious, Document Frequency: 18
# Token: design, Document Frequency: 9
# Token: dessert, Document Frequency: 5
# Token: device, Document Frequency: 7
# Token: dialogue, Document Frequency: 12
# Token: did, Document Frequency: 40
# Token: didn, Document Frequency: 37
# Token: different, Document Frequency: 11
# Token: difficult, Document Frequency: 6
# Token: directing, Document Frequency: 6
# Token: direction, Document Frequency: 5
# Token: director, Document Frequency: 11
# Token: disappointed, Document Frequency: 32
# Token: disappointing, Document Frequency: 11
# Token: disappointment, Document Frequency: 9
# Token: dish, Document Frequency: 6
# Token: dishes, Document Frequency: 7
# Token: do, Document Frequency: 41
# Token: does, Document Frequency: 28
# Token: doesn, Document Frequency: 24
# Token: don, Document Frequency: 63
# Token: done, Document Frequency: 12
# Token: down, Document Frequency: 18
# Token: drama, Document Frequency: 6
# Token: drive, Document Frequency: 6
# Token: dropped, Document Frequency: 8
# Token: during, Document Frequency: 9
# Token: each, Document Frequency: 13
# Token: ear, Document Frequency: 29
# Token: ears, Document Frequency: 6
# Token: easily, Document Frequency: 9
# Token: easy, Document Frequency: 18
# Token: eat, Document Frequency: 16
# Token: eaten, Document Frequency: 5
# Token: eating, Document Frequency: 7
# Token: effects, Document Frequency: 9
# Token: either, Document Frequency: 11
# Token: else, Document Frequency: 8
# Token: elsewhere, Document Frequency: 6
# Token: empty, Document Frequency: 5
# Token: end, Document Frequency: 15
# Token: ended, Document Frequency: 5
# Token: ending, Document Frequency: 11
# Token: enjoy, Document Frequency: 10
# Token: enjoyed, Document Frequency: 11
# Token: enough, Document Frequency: 29
# Token: entire, Document Frequency: 6
# Token: especially, Document Frequency: 15
# Token: even, Document Frequency: 65
# Token: ever, Document Frequency: 63
# Token: every, Document Frequency: 31
# Token: everyone, Document Frequency: 12
# Token: everything, Document Frequency: 27
# Token: exactly, Document Frequency: 6
# Token: excellent, Document Frequency: 47
# Token: expect, Document Frequency: 13
# Token: expected, Document Frequency: 8
# Token: experience, Document Frequency: 21
# Token: extra, Document Frequency: 6
# Token: extremely, Document Frequency: 6
# Token: eyes, Document Frequency: 5
# Token: face, Document Frequency: 9
# Token: fact, Document Frequency: 11
# Token: family, Document Frequency: 17
# Token: fantastic, Document Frequency: 14
# Token: far, Document Frequency: 24
# Token: fast, Document Frequency: 12
# Token: feature, Document Frequency: 5
# Token: feel, Document Frequency: 12
# Token: feeling, Document Frequency: 9
# Token: feels, Document Frequency: 5
# Token: felt, Document Frequency: 11
# Token: few, Document Frequency: 22
# Token: film, Document Frequency: 127
# Token: films, Document Frequency: 21
# Token: finally, Document Frequency: 5
# Token: find, Document Frequency: 17
# Token: fine, Document Frequency: 18
# Token: first, Document Frequency: 39
# Token: fish, Document Frequency: 5
# Token: fit, Document Frequency: 12
# Token: fits, Document Frequency: 9
# Token: flavor, Document Frequency: 11
# Token: food, Document Frequency: 101
# Token: for, Document Frequency: 258
# Token: found, Document Frequency: 14
# Token: free, Document Frequency: 8
# Token: fresh, Document Frequency: 11
# Token: fried, Document Frequency: 5
# Token: friendly, Document Frequency: 23
# Token: friends, Document Frequency: 6
# Token: fries, Document Frequency: 7
# Token: from, Document Frequency: 76
# Token: full, Document Frequency: 12
# Token: fun, Document Frequency: 9
# Token: funny, Document Frequency: 15
# Token: game, Document Frequency: 9
# Token: garbage, Document Frequency: 6
# Token: gave, Document Frequency: 10
# Token: get, Document Frequency: 42
# Token: gets, Document Frequency: 13
# Token: getting, Document Frequency: 10
# Token: girl, Document Frequency: 5
# Token: give, Document Frequency: 23
# Token: given, Document Frequency: 5
# Token: glad, Document Frequency: 8
# Token: go, Document Frequency: 54
# Token: goes, Document Frequency: 5
# Token: going, Document Frequency: 27
# Token: good, Document Frequency: 186
# Token: got, Document Frequency: 27
# Token: great, Document Frequency: 165
# Token: guess, Document Frequency: 8
# Token: had, Document Frequency: 109
# Token: half, Document Frequency: 8
# Token: hand, Document Frequency: 5
# Token: hands, Document Frequency: 8
# Token: happened, Document Frequency: 5
# Token: happy, Document Frequency: 17
# Token: hard, Document Frequency: 11
# Token: has, Document Frequency: 69
# Token: hate, Document Frequency: 8
# Token: have, Document Frequency: 148
# Token: having, Document Frequency: 12
# Token: he, Document Frequency: 54
# Token: headphones, Document Frequency: 5
# Token: headset, Document Frequency: 39
# Token: headsets, Document Frequency: 6
# Token: hear, Document Frequency: 11
# Token: heart, Document Frequency: 7
# Token: helpful, Document Frequency: 5
# Token: her, Document Frequency: 25
# Token: here, Document Frequency: 61
# Token: high, Document Frequency: 9
# Token: highly, Document Frequency: 20
# Token: him, Document Frequency: 7
# Token: his, Document Frequency: 42
# Token: history, Document Frequency: 6
# Token: hitchcock, Document Frequency: 6
# Token: hold, Document Frequency: 5
# Token: holds, Document Frequency: 5
# Token: home, Document Frequency: 6
# Token: hope, Document Frequency: 7
# Token: horrible, Document Frequency: 17
# Token: horror, Document Frequency: 7
# Token: hot, Document Frequency: 7
# Token: hour, Document Frequency: 12
# Token: hours, Document Frequency: 9
# Token: house, Document Frequency: 8
# Token: how, Document Frequency: 41
# Token: however, Document Frequency: 14
# Token: huge, Document Frequency: 11
# Token: human, Document Frequency: 7
# Token: ice, Document Frequency: 5
# Token: if, Document Frequency: 85
# Token: important, Document Frequency: 7
# Token: impressed, Document Frequency: 14
# Token: incredible, Document Frequency: 10
# Token: inside, Document Frequency: 8
# Token: instead, Document Frequency: 5
# Token: interesting, Document Frequency: 13
# Token: internet, Document Frequency: 6
# Token: into, Document Frequency: 23
# Token: item, Document Frequency: 18
# Token: its, Document Frequency: 33
# Token: itself, Document Frequency: 7
# Token: jabra, Document Frequency: 7
# Token: job, Document Frequency: 13
# Token: john, Document Frequency: 6
# Token: joy, Document Frequency: 6
# Token: junk, Document Frequency: 8
# Token: just, Document Frequency: 90
# Token: keep, Document Frequency: 7
# Token: kept, Document Frequency: 9
# Token: kids, Document Frequency: 7
# Token: kind, Document Frequency: 15
# Token: know, Document Frequency: 24
# Token: lacking, Document Frequency: 5
# Token: lacks, Document Frequency: 5
# Token: large, Document Frequency: 5
# Token: last, Document Frequency: 15
# Token: lead, Document Frequency: 5
# Token: least, Document Frequency: 13
# Token: leather, Document Frequency: 5
# Token: leave, Document Frequency: 5
# Token: left, Document Frequency: 12
# Token: less, Document Frequency: 9
# Token: let, Document Frequency: 5
# Token: life, Document Frequency: 22
# Token: light, Document Frequency: 6
# Token: like, Document Frequency: 97
# Token: liked, Document Frequency: 11
# Token: line, Document Frequency: 16
# Token: lines, Document Frequency: 6
# Token: list, Document Frequency: 5
# Token: literally, Document Frequency: 6
# Token: little, Document Frequency: 31
# Token: living, Document Frequency: 6
# Token: ll, Document Frequency: 18
# Token: long, Document Frequency: 17
# Token: look, Document Frequency: 23
# Token: looked, Document Frequency: 6
# Token: looking, Document Frequency: 9
# Token: looks, Document Frequency: 12
# Token: lost, Document Frequency: 7
# Token: lot, Document Frequency: 17
# Token: love, Document Frequency: 51
# Token: loved, Document Frequency: 18
# Token: lovely, Document Frequency: 5
# Token: low, Document Frequency: 12
# Token: lunch, Document Frequency: 9
# Token: made, Document Frequency: 48
# Token: make, Document Frequency: 39
# Token: makes, Document Frequency: 15
# Token: making, Document Frequency: 5
# Token: man, Document Frequency: 12
# Token: management, Document Frequency: 6
# Token: many, Document Frequency: 23
# Token: may, Document Frequency: 11
# Token: me, Document Frequency: 55
# Token: meal, Document Frequency: 9
# Token: meat, Document Frequency: 8
# Token: mediocre, Document Frequency: 9
# Token: mention, Document Frequency: 7
# Token: menu, Document Frequency: 10
# Token: mess, Document Frequency: 7
# Token: might, Document Frequency: 7
# Token: mind, Document Frequency: 7
# Token: minutes, Document Frequency: 26
# Token: mobile, Document Frequency: 5
# Token: money, Document Frequency: 26
# Token: months, Document Frequency: 8
# Token: more, Document Frequency: 48
# Token: most, Document Frequency: 36
# Token: mostly, Document Frequency: 6
# Token: motorola, Document Frequency: 10
# Token: movie, Document Frequency: 145
# Token: movies, Document Frequency: 27
# Token: moving, Document Frequency: 5
# Token: much, Document Frequency: 40
# Token: music, Document Frequency: 16
# Token: must, Document Frequency: 15
# Token: my, Document Frequency: 206
# Token: myself, Document Frequency: 5
# Token: need, Document Frequency: 9
# Token: needed, Document Frequency: 5
# Token: needs, Document Frequency: 5
# Token: never, Document Frequency: 37
# Token: new, Document Frequency: 23
# Token: next, Document Frequency: 12
# Token: nice, Document Frequency: 41
# Token: night, Document Frequency: 17
# Token: no, Document Frequency: 57
# Token: nokia, Document Frequency: 6
# Token: non, Document Frequency: 6
# Token: none, Document Frequency: 6
# Token: not, Document Frequency: 244
# Token: note, Document Frequency: 5
# Token: nothing, Document Frequency: 21
# Token: now, Document Frequency: 34
# Token: obviously, Document Frequency: 6
# Token: off, Document Frequency: 28
# Token: offers, Document Frequency: 5
# Token: oh, Document Frequency: 9
# Token: old, Document Frequency: 15
# Token: on, Document Frequency: 178
# Token: once, Document Frequency: 10
# Token: one, Document Frequency: 115
# Token: only, Document Frequency: 65
# Token: or, Document Frequency: 65
# Token: order, Document Frequency: 12
# Token: ordered, Document Frequency: 16
# Token: original, Document Frequency: 7
# Token: other, Document Frequency: 37
# Token: others, Document Frequency: 5
# Token: our, Document Frequency: 41
# Token: out, Document Frequency: 81
# Token: outside, Document Frequency: 7
# Token: over, Document Frequency: 30
# Token: overall, Document Frequency: 13
# Token: overpriced, Document Frequency: 7
# Token: own, Document Frequency: 9
# Token: part, Document Frequency: 14
# Token: pathetic, Document Frequency: 5
# Token: pay, Document Frequency: 7
# Token: people, Document Frequency: 23
# Token: perfect, Document Frequency: 15
# Token: perfectly, Document Frequency: 12
# Token: performance, Document Frequency: 12
# Token: perhaps, Document Frequency: 7
# Token: pho, Document Frequency: 5
# Token: phone, Document Frequency: 142
# Token: phones, Document Frequency: 6
# Token: picture, Document Frequency: 6
# Token: pictures, Document Frequency: 8
# Token: piece, Document Frequency: 22
# Token: pizza, Document Frequency: 12
# Token: place, Document Frequency: 100
# Token: places, Document Frequency: 6
# Token: plain, Document Frequency: 5
# Token: plastic, Document Frequency: 6
# Token: play, Document Frequency: 10
# Token: played, Document Frequency: 7
# Token: playing, Document Frequency: 8
# Token: pleased, Document Frequency: 9
# Token: plot, Document Frequency: 24
# Token: plug, Document Frequency: 11
# Token: plus, Document Frequency: 8
# Token: point, Document Frequency: 7
# Token: poor, Document Frequency: 23
# Token: poorly, Document Frequency: 5
# Token: portions, Document Frequency: 5
# Token: portrayal, Document Frequency: 5
# Token: possible, Document Frequency: 6
# Token: predictable, Document Frequency: 8
# Token: pretty, Document Frequency: 33
# Token: price, Document Frequency: 30
# Token: priced, Document Frequency: 6
# Token: prices, Document Frequency: 9
# Token: probably, Document Frequency: 21
# Token: problem, Document Frequency: 12
# Token: problems, Document Frequency: 13
# Token: product, Document Frequency: 47
# Token: purchase, Document Frequency: 9
# Token: put, Document Frequency: 11
# Token: quality, Document Frequency: 52
# Token: quick, Document Frequency: 8
# Token: quickly, Document Frequency: 5
# Token: quite, Document Frequency: 18
# Token: range, Document Frequency: 6
# Token: rare, Document Frequency: 5
# Token: rated, Document Frequency: 5
# Token: rather, Document Frequency: 10
# Token: rating, Document Frequency: 6
# Token: re, Document Frequency: 11
# Token: real, Document Frequency: 25
# Token: really, Document Frequency: 79
# Token: reason, Document Frequency: 5
# Token: reasonable, Document Frequency: 6
# Token: received, Document Frequency: 10
# Token: reception, Document Frequency: 14
# Token: recommend, Document Frequency: 44
# Token: recommended, Document Frequency: 9
# Token: rent, Document Frequency: 5
# Token: restaurant, Document Frequency: 22
# Token: return, Document Frequency: 10
# Token: review, Document Frequency: 7
# Token: ridiculous, Document Frequency: 6
# Token: right, Document Frequency: 28
# Token: room, Document Frequency: 6
# Token: rude, Document Frequency: 8
# Token: running, Document Frequency: 5
# Token: sad, Document Frequency: 5
# Token: said, Document Frequency: 17
# Token: salad, Document Frequency: 11
# Token: same, Document Frequency: 16
# Token: sandwich, Document Frequency: 6
# Token: sauce, Document Frequency: 8
# Token: saw, Document Frequency: 10
# Token: say, Document Frequency: 27
# Token: scene, Document Frequency: 11
# Token: scenes, Document Frequency: 14
# Token: screen, Document Frequency: 22
# Token: script, Document Frequency: 19
# Token: seafood, Document Frequency: 5
# Token: seated, Document Frequency: 5
# Token: second, Document Frequency: 9
# Token: see, Document Frequency: 38
# Token: seeing, Document Frequency: 6
# Token: seems, Document Frequency: 8
# Token: seen, Document Frequency: 21
# Token: selection, Document Frequency: 8
# Token: self, Document Frequency: 6
# Token: series, Document Frequency: 7
# Token: seriously, Document Frequency: 10
# Token: served, Document Frequency: 6
# Token: server, Document Frequency: 11
# Token: servers, Document Frequency: 5
# Token: service, Document Frequency: 86
# Token: set, Document Frequency: 9
# Token: setting, Document Frequency: 6
# Token: several, Document Frequency: 9
# Token: she, Document Frequency: 17
# Token: short, Document Frequency: 9
# Token: should, Document Frequency: 16
# Token: show, Document Frequency: 18
# Token: shrimp, Document Frequency: 6
# Token: sick, Document Frequency: 5
# Token: side, Document Frequency: 7
# Token: sides, Document Frequency: 5
# Token: signal, Document Frequency: 6
# Token: simple, Document Frequency: 8
# Token: simply, Document Frequency: 10
# Token: since, Document Frequency: 18
# Token: single, Document Frequency: 7
# Token: slow, Document Frequency: 15
# Token: small, Document Frequency: 15
# Token: so, Document Frequency: 142
# Token: software, Document Frequency: 7
# Token: solid, Document Frequency: 5
# Token: some, Document Frequency: 45
# Token: someone, Document Frequency: 8
# Token: something, Document Frequency: 5
# Token: sometimes, Document Frequency: 5
# Token: soon, Document Frequency: 10
# Token: sound, Document Frequency: 42
# Token: special, Document Frequency: 12
# Token: spicy, Document Frequency: 6
# Token: spot, Document Frequency: 8
# Token: staff, Document Frequency: 17
# Token: star, Document Frequency: 10
# Token: stars, Document Frequency: 19
# Token: started, Document Frequency: 10
# Token: stay, Document Frequency: 9
# Token: steak, Document Frequency: 13
# Token: still, Document Frequency: 35
# Token: store, Document Frequency: 7
# Token: story, Document Frequency: 22
# Token: strong, Document Frequency: 8
# Token: stupid, Document Frequency: 15
# Token: style, Document Frequency: 7
# Token: subtle, Document Frequency: 5
# Token: such, Document Frequency: 16
# Token: sucked, Document Frequency: 11
# Token: sucks, Document Frequency: 7
# Token: super, Document Frequency: 12
# Token: superb, Document Frequency: 5
# Token: sure, Document Frequency: 12
# Token: sushi, Document Frequency: 12
# Token: suspense, Document Frequency: 5
# Token: sweet, Document Frequency: 6
# Token: table, Document Frequency: 8
# Token: take, Document Frequency: 19
# Token: talk, Document Frequency: 15
# Token: taste, Document Frequency: 9
# Token: tasted, Document Frequency: 7
# Token: tasty, Document Frequency: 6
# Token: tell, Document Frequency: 10
# Token: tender, Document Frequency: 5
# Token: terrible, Document Frequency: 24
# Token: than, Document Frequency: 52
# Token: that, Document Frequency: 241
# Token: their, Document Frequency: 37
# Token: them, Document Frequency: 38
# Token: then, Document Frequency: 25
# Token: there, Document Frequency: 95
# Token: these, Document Frequency: 28
# Token: they, Document Frequency: 81
# Token: thin, Document Frequency: 5
# Token: thing, Document Frequency: 26
# Token: things, Document Frequency: 16
# Token: think, Document Frequency: 36
# Token: those, Document Frequency: 16
# Token: though, Document Frequency: 15
# Token: thought, Document Frequency: 17
# Token: three, Document Frequency: 10
# Token: through, Document Frequency: 10
# Token: throughout, Document Frequency: 6
# Token: time, Document Frequency: 85
# Token: times, Document Frequency: 20
# Token: today, Document Frequency: 7
# Token: together, Document Frequency: 9
# Token: told, Document Frequency: 7
# Token: too, Document Frequency: 43
# Token: took, Document Frequency: 9
# Token: top, Document Frequency: 7
# Token: totally, Document Frequency: 17
# Token: town, Document Frequency: 6
# Token: tried, Document Frequency: 10
# Token: truly, Document Frequency: 9
# Token: try, Document Frequency: 14
# Token: trying, Document Frequency: 8
# Token: turn, Document Frequency: 7
# Token: tv, Document Frequency: 10
# Token: twice, Document Frequency: 7
# Token: two, Document Frequency: 27
# Token: under, Document Frequency: 8
# Token: understand, Document Frequency: 10
# Token: unfortunately, Document Frequency: 9
# Token: unit, Document Frequency: 5
# Token: unless, Document Frequency: 7
# Token: until, Document Frequency: 5
# Token: up, Document Frequency: 58
# Token: us, Document Frequency: 23
# Token: use, Document Frequency: 40
# Token: used, Document Frequency: 18
# Token: useless, Document Frequency: 7
# Token: using, Document Frequency: 11
# Token: value, Document Frequency: 5
# Token: ve, Document Frequency: 46
# Token: vegas, Document Frequency: 17
# Token: verizon, Document Frequency: 6
# Token: very, Document Frequency: 204
# Token: voice, Document Frequency: 9
# Token: volume, Document Frequency: 8
# Token: wait, Document Frequency: 10
# Token: waited, Document Frequency: 9
# Token: waiter, Document Frequency: 7
# Token: waiting, Document Frequency: 6
# Token: waitress, Document Frequency: 7
# Token: walked, Document Frequency: 6
# Token: wall, Document Frequency: 5
# Token: want, Document Frequency: 19
# Token: wanted, Document Frequency: 9
# Token: warm, Document Frequency: 6
# Token: wasn, Document Frequency: 19
# Token: waste, Document Frequency: 27
# Token: wasted, Document Frequency: 8
# Token: watch, Document Frequency: 14
# Token: watched, Document Frequency: 9
# Token: watching, Document Frequency: 18
# Token: way, Document Frequency: 37
# Token: we, Document Frequency: 90
# Token: weak, Document Frequency: 6
# Token: wear, Document Frequency: 8
# Token: week, Document Frequency: 6
# Token: well, Document Frequency: 74
# Token: went, Document Frequency: 18
# Token: were, Document Frequency: 92
# Token: what, Document Frequency: 51
# Token: whatever, Document Frequency: 5
# Token: whatsoever, Document Frequency: 5
# Token: when, Document Frequency: 52
# Token: where, Document Frequency: 11
# Token: whether, Document Frequency: 6
# Token: which, Document Frequency: 46
# Token: while, Document Frequency: 22
# Token: white, Document Frequency: 11
# Token: who, Document Frequency: 44
# Token: whole, Document Frequency: 10
# Token: why, Document Frequency: 10
# Token: wife, Document Frequency: 8
# Token: will, Document Frequency: 57
# Token: with, Document Frequency: 214
# Token: within, Document Frequency: 6
# Token: without, Document Frequency: 13
# Token: won, Document Frequency: 21
# Token: wonderful, Document Frequency: 24
# Token: word, Document Frequency: 8
# Token: work, Document Frequency: 43
# Token: worked, Document Frequency: 17
# Token: working, Document Frequency: 13
# Token: works, Document Frequency: 42
# Token: world, Document Frequency: 8
# Token: worse, Document Frequency: 11
# Token: worst, Document Frequency: 29
# Token: worth, Document Frequency: 21
# Token: would, Document Frequency: 78
# Token: wouldn, Document Frequency: 6
# Token: writing, Document Frequency: 10
# Token: written, Document Frequency: 5
# Token: wrong, Document Frequency: 8
# Token: year, Document Frequency: 13
# Token: years, Document Frequency: 20
# Token: yet, Document Frequency: 8
# Token: you, Document Frequency: 177
# Token: your, Document Frequency: 66
# Token: zero, Document Frequency: 6

# %% [markdown]
# ### Perform Grid Search

# %%
# Create a pipeline for text classification
my_bow_classifier_pipeline = sklearn.pipeline.Pipeline([
    ('my_bow_feature_extractor', CountVectorizer(preprocessor=combined_preprocessor, min_df=1, max_df=0.09, ngram_range=(1, 1))),
    ('my_classifier', sklearn.linear_model.LogisticRegression(C=1.0, max_iter=1000, random_state=1)),
])

# Define a parameter grid for hyperparameter tuning
my_parameter_grid_by_name = dict()
my_parameter_grid_by_name['my_bow_feature_extractor__min_df'] = [5, 10, 15, 20, 80, 140, 160]
my_parameter_grid_by_name['my_bow_feature_extractor__max_df'] = [0.1, 0.2, 0.4, 0.8, 1.0]
my_parameter_grid_by_name['my_classifier__C'] = np.logspace(-4, 4, 9)

# Choose a scoring metric for model evaluation
my_scoring_metric_name = 'roc_auc'

# Create a KFold object for cross-validation with 10 folds
k_fold = sklearn.model_selection.KFold(n_splits=5, shuffle=True, random_state=0)

# Use GridSearchCV for hyperparameter tuning with cross-validation
grid_searcher = sklearn.model_selection.GridSearchCV(
    my_bow_classifier_pipeline,  # The model pipeline
    my_parameter_grid_by_name,  # The parameter grid to search
    scoring=my_scoring_metric_name,  # The evaluation metric
    cv=k_fold,  # 10-fold cross-validation
    refit=True,  # Refit the best model
    return_train_score=True # Receive training scores

)

# Shuffle the data before feeding it into the model
rand_text_col_arr, rand_results_col_arr = shuffle(text_col_arr, results_col_arr, random_state=1)

# Fit the grid search to find the best model and hyperparameters
grid_searcher.fit(rand_text_col_arr, rand_results_col_arr)
# Out:
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#              estimator=Pipeline(steps=[('my_bow_feature_extractor',
#                                         CountVectorizer(max_df=0.09,
#                                                         preprocessor=<function combined_preprocessor at 0x00000152BD3011B0>)),
#                                        ('my_classifier',
#                                         LogisticRegression(max_iter=1000,
#                                                            random_state=1))]),
#              param_grid={'my_bow_feature_extractor__max_df': [0.1, 0.2, 0.4,
#                                                               0.8, 1.0],
#                          'my_bow_feature_extractor__min_df': [5, 10, 15, 20, 80,
#                                                               140, 160],
#                          'my_classifier__C': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])},
#              return_train_score=True, scoring='roc_auc')

# %%
cv_results_df = pd.DataFrame(grid_searcher.cv_results_)
print(cv_results_df)

file_path = "cv_results.csv"
cv_results_df.to_scv(file_path, index=False)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.080491      0.030430         0.021048        0.009130
# 1         0.066919      0.014789         0.018920        0.005985
# 2         0.081261      0.019145         0.017391        0.002642
# 3         0.072217      0.006253         0.014965        0.001848
# 4         0.133173      0.047278         0.021149        0.004195
# ..             ...           ...              ...             ...
# 310       0.066359      0.005733         0.015327        0.000421
# 311       0.077450      0.013788         0.018507        0.004777
# 312       0.066034      0.003025         0.015271        0.000479
# 313       0.065641      0.001551         0.017405        0.004316
# 314       0.064310      0.000680         0.016207        0.002163
#
#     param_my_bow_feature_extractor__max_df  \
# 0                                      0.1
# 1                                      0.1
# 2                                      0.1
# 3                                      0.1
# 4                                      0.1
# ..                                     ...
# 310                                    1.0
# 311                                    1.0
# 312                                    1.0
# 313                                    1.0
# 314                                    1.0
#
#     param_my_bow_feature_extractor__min_df param_my_classifier__C  \
# 0                                        5                 0.0001
# 1                                        5                  0.001
# 2                                        5                   0.01
# 3                                        5                    0.1
# 4                                        5                    1.0
# ..                                     ...                    ...
# 310                                    160                    1.0
# 311                                    160                   10.0
# 312                                    160                  100.0
# 313                                    160                 1000.0
# 314                                    160                10000.0
#
#                                                 params  split0_test_score  \
# 0    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.817716
# 1    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.820564
# 2    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.839340
# 3    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.874581
# 4    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.881198
# ..                                                 ...                ...
# 310  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621937
# 311  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
# 312  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
# 313  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
# 314  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
#
#      split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0             0.751685  ...         0.796887        0.030160               73
# 1             0.752103  ...         0.799176        0.030493               64
# 2             0.757936  ...         0.815287        0.032121               31
# 3             0.785830  ...         0.848177        0.032584                6
# 4             0.811043  ...         0.860191        0.027438                1
# ..                 ...  ...              ...             ...              ...
# 310           0.587305  ...         0.631236        0.028307              250
# 311           0.587932  ...         0.631205        0.028061              258
# 312           0.587827  ...         0.631215        0.028112              252
# 313           0.587827  ...         0.631208        0.028104              254
# 314           0.587827  ...         0.631208        0.028104              254
#
#      split0_train_score  split1_train_score  split2_train_score  \
# 0              0.844372            0.857139            0.847453
# 1              0.847366            0.860249            0.850709
# 2              0.868903            0.881039            0.872750
# 3              0.920649            0.929119            0.925703
# 4              0.961274            0.964100            0.965631
# ..                  ...                 ...                 ...
# 310            0.645321            0.655272            0.636506
# 311            0.645109            0.655107            0.636331
# 312            0.645084            0.654944            0.636308
# 313            0.645226            0.654948            0.636311
# 314            0.645225            0.654948            0.636309
#
#      split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0              0.836946            0.839856          0.845153         0.007000
# 1              0.840244            0.843692          0.848452         0.006863
# 2              0.864455            0.868457          0.871121         0.005612
# 3              0.919536            0.919989          0.922999         0.003778
# 4              0.961456            0.960555          0.962603         0.001933
# ..                  ...                 ...               ...              ...
# 310            0.642249            0.642140          0.644298         0.006181
# 311            0.642438            0.642207          0.644238         0.006145
# 312            0.642446            0.642225          0.644201         0.006091
# 313            0.642441            0.642225          0.644230         0.006096
# 314            0.642441            0.642227          0.644230         0.006096
#
# [315 rows x 23 columns]

# %% [markdown]
# ### HyperParameter Selection for Logistic Regression Classifier

# %%
# Extract the relevant data for 'my_classifier__C' hyperparameter
hyperparameter_values = grid_searcher.cv_results_['param_my_classifier__C']
mean_train_scores = grid_searcher.cv_results_['mean_train_score']
mean_test_scores = grid_searcher.cv_results_['mean_test_score']

# Save raw hyperparameter values
hyperparameter_values_str = hyperparameter_values.astype(str)

# Create a DataFrame for hyperparameter vs AUROC
df = pd.DataFrame({'C Value': hyperparameter_values_str,
                   'Train AUROC': mean_train_scores,
                   'Validation AUROC': mean_test_scores})

# Use Seaborn to create line plots
plt.figure(figsize=(10, 6))
ax = sns.lineplot(x='C Value', y='Train AUROC', data=df, label='Training AUROC')
ax = sns.lineplot(x='C Value', y='Validation AUROC', data=df, label='Validation AUROC')

# Label the axes, title, and legend
plt.xlabel('C Value')
plt.ylabel('AUROC')
plt.title("Average ROC on Training and Validation Sets vs. C Values")
plt.legend()
plt.show()

# Across all combinations of max_df and min_df values, models that have the C value of 1.0 produce the best validation result.
# The blue and the orangelines are the average training and validation performance based on all combinations of max_df and min_df across all.

# %% [markdown]
# ### Analysis of Predictions for the Best Classifier

# %%
import random
from sklearn.metrics import confusion_matrix


# Print best parameters
print('Best Parameters:', grid_searcher.best_params_)


# Prepare the the test data
our_test_x_arr =  our_test_x_df['text'].values
our_test_y_arr = np.ravel(our_test_y_df.values)

# Preprocess the x values
our_reprocessor = my_bow_classifier_pipeline.named_steps['my_bow_feature_extractor'].build_preprocessor()
our_preprocessed_test = [our_reprocessor(doc) for doc in our_test_x_arr]

# Predict the y values
best_model = grid_searcher.best_estimator_
model_test_y_arr = best_model.predict_proba(our_preprocessed_test)[:,1]


# Define a threshold for classification
threshold = 0.5

# Classify predictions using the threshold
predicted_labels = (model_test_y_arr > threshold).astype(int)


# Create the confusion matrix
confusion = confusion_matrix(our_test_y_arr, predicted_labels)


# Find the indices of false positives and false negatives

# true_positive_indicies = np.where((predicted_labels == 1) & (our_test_y_arr == 1))[0]
# true_negatives_indicies = np.where((predicted_labels == 0) & (our_test_y_arr == 0))[0]
false_positive_indices = np.where((predicted_labels == 1) & (our_test_y_arr == 0))[0]
false_negative_indices = np.where((predicted_labels == 0) & (our_test_y_arr == 1))[0]

# Create lists of false positives and false negatives

# true_positives = [our_test_x_arr[i] for i in true_positive_indicies]
# true_negatives = [our_test_x_arr[i] for i in true_negatives_indicies]
false_positives = [our_test_x_arr[i] for i in false_positive_indices]
false_negatives = [our_test_x_arr[i] for i in false_negative_indices]


# print(len(true_positives))
# print(len(true_negatives))
print(len(false_positives))
print(len(false_negatives))

# Plot the confusion matrix using seaborn
sns.set(font_scale=1.4)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["Predicted 0", "Predicted 1"],
            yticklabels=["Actual 0", "Actual 1"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()


# Create a text file and write the sentences into it
with open('false_positives_and_negatives.txt', 'w', encoding='utf-8') as file:
    file.write("False Positives:\n")
    for fp in false_positives:
        if fp:
            file.write(fp + '\n')

    file.write("\nFalse Negatives:\n")
    for fn in false_negatives:
        if fn:
            file.write(fn + '\n')


# Analysis paragraph
# plt.figtext(0.1, -0.1, "Analysis: \n\n1. Sentence Length: \n2. Review Types: \n3. Negation Words:", fontsize=12)

# plt.show()

# # Produce the ROC Curve
# fpr, tpr, thresholds= sklearn.metrics.roc_curve(our_test_y_arr, model_test_y_arr)


# plt.plot(fpr, tpr, color ='b', lw=2, label='Best Model', linestyle='-.');

# plt.title("ROC on Test Set");
# plt.xlabel('false positive rate');
# plt.ylabel('true positive rate');
# plt.legend(loc='lower right');
# B = 0.01
# plt.xlim([0 - B, 1 + B]);
# plt.ylim([0 - B, 1 + B]);
# Out:
# Best Parameters: {'my_bow_feature_extractor__max_df': 0.1, 'my_bow_feature_extractor__min_df': 5, 'my_classifier__C': 1.0}
# 9
# 17

# %% [markdown]
# ### Performance on Test Set via Leaderboard

# %%
# Retrieve the preprocessor
preprocessor = my_bow_classifier_pipeline.named_steps['my_bow_feature_extractor'].build_preprocessor()

