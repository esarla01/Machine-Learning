# %% [markdown]
# # HW5 : Kernel Methods for Regression
#
# Official instructions:
#
# https://www.cs.tufts.edu/cs/135/2023f/hw5.html
#
# This is the starter code notebook.
#
# ## IMPORTANT:
#
# Make sure that you have implemented the kernel functions in `linear_kernel.py` and `sqexp_kernel.py`

# %% [markdown]
# ## Import relevant packages

# %%
import numpy as np
import pandas as pd
import os
import sys
import time
import importlib
import itertools

# %%
import sklearn.linear_model
import sklearn.pipeline
import sklearn.metrics

# %%
# Plotting utils
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Load Training set data for the 'ByYear' split

# %%
DATA_DIR = os.path.join("data_melbourne_daily_min_temp/") #TODO: fix it to your local file structure

# %%
data_trByYear_df = pd.read_csv(os.path.join(DATA_DIR, 'data_train_ByYear.csv'))

# %%
# Inspect the first few entries
data_trByYear_df.head()
# Out:
#          date  years_since_19850101  temp_deg_C
# 0  1981-01-01             -4.002740        20.7
# 1  1981-01-02             -4.000000        17.9
# 2  1981-01-03             -3.997260        18.8
# 3  1981-01-04             -3.994521        14.6
# 4  1981-01-05             -3.991781        15.8

# %%
# Inspect the last few entries
data_trByYear_df.tail()
# Out:
#             date  years_since_19850101  temp_deg_C
# 2185  1986-12-27              1.986301        14.6
# 2186  1986-12-28              1.989041        14.2
# 2187  1986-12-29              1.991781        13.2
# 2188  1986-12-30              1.994521        11.7
# 2189  1986-12-31              1.997260        17.2

# %%
# Read relevant columns into numpy arrays for x and y

x_trByYear_N1 = data_trByYear_df['years_since_19850101'].values[:][:,np.newaxis].copy()
y_trByYear_N = data_trByYear_df['temp_deg_C'].values[:].copy()

print("Training data (ByYear split strategy)")
print("x_trByYear_N1.shape: %s" % str(x_trByYear_N1.shape))
print("y_trByYear_N.shape : %s" % str(y_trByYear_N.shape))
print("mean(y_trByYear_N) : %.3f" % np.mean(y_trByYear_N))
# Out:
# Training data (ByYear split strategy)
# x_trByYear_N1.shape: (2190, 1)
# y_trByYear_N.shape : (2190,)
# mean(y_trByYear_N) : 11.003

# %% [markdown]
# # Load Validation set data for the 'ByYear' split

# %%
data_vaByYear_df = pd.read_csv(os.path.join(DATA_DIR, 'data_valid_ByYear.csv'))

data_vaByYear_df.head()
# Out:
#          date  years_since_19850101  temp_deg_C
# 0  1987-01-01              2.000000        12.3
# 1  1987-01-02              2.002740        13.8
# 2  1987-01-03              2.005479        15.3
# 3  1987-01-04              2.008219        15.6
# 4  1987-01-05              2.010959        16.2

# %%
x_vaByYear_T1 = data_vaByYear_df['years_since_19850101'].values[:][:,np.newaxis].copy()
y_vaByYear_T = data_vaByYear_df['temp_deg_C'].values[:].copy()

print("Validation data (ByYear split strategy)")
print("x_vaByYear_T1.shape: %s" % str(x_vaByYear_T1.shape))
print("y_vaByYear_T.shape : %s" % str(y_vaByYear_T.shape))
print("mean(y_vaByYear_T) : %.3f" % np.mean(y_vaByYear_T))
# Out:
# Validation data (ByYear split strategy)
# x_vaByYear_T1.shape: (730, 1)
# y_vaByYear_T.shape : (730,)
# mean(y_vaByYear_T) : 11.413

# %% [markdown]
# # Plot both training and validation sets

# %%
fig, axgrid = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(16,5))

axgrid[0].plot(x_trByYear_N1, y_trByYear_N, 'bs', alpha=0.4)
axgrid[0].set_xlabel('x : Fractional Years since 1985');
axgrid[0].set_title('Training Set (%d examples, %s-%s)' % (
    y_trByYear_N.size,
    pd.to_datetime(data_trByYear_df['date'].values[0]).year,
    pd.to_datetime(data_trByYear_df['date'].values[-1]).year))

axgrid[1].plot(x_vaByYear_T1, y_vaByYear_T, 'cs', alpha=0.4)
axgrid[1].set_xlabel('x : Fractional Years since 1985');
axgrid[1].set_title('Validation Set (%d examples, %s-%s)' % (
    y_vaByYear_T.size,
    pd.to_datetime(data_vaByYear_df['date'].values[0]).year,
    pd.to_datetime(data_vaByYear_df['date'].values[-1]).year))

axgrid[0].set_ylabel("y : Min Daily Temp (deg C)");
plt.tight_layout();

# %%
# Make a placeholder for the kernels to be used
def identity_kernel(x_QF, x_train_NF=None, length_scale=None, period=None):
    return x_QF

# %%
from linear_kernel import calc_linear_kernel
from sqexp_kernel import calc_sqexp_kernel
from periodic_kernel import calc_periodic_kernel

# %% [markdown]
# # Prepare to use sklearn splitter tools for hyperparameter search

# %% [markdown]
# ### Prep the ByYear splitter

# %%
x_all_ByYear_L1 = np.vstack([x_trByYear_N1, x_vaByYear_T1])
y_all_ByYear_L = np.hstack([y_trByYear_N, y_vaByYear_T])

# %%
# Create splitter object using Predefined Split
my_ByYear_splitter = sklearn.model_selection.PredefinedSplit(np.hstack([
    -1 * np.ones(y_trByYear_N.size), # -1 means never include this example in any 'test' split for grid search
    0  * np.ones(y_vaByYear_T.size), #  0 means include in the first test split (we count starting at 0 in python)
    ]))

# %% [markdown]
# # Define utility function to make pretty plots of predictions for each model

# %%
def plot_data_and_predictions(model, model_legend_text='INSERT YOUR TEXT HERE'):
    plt.plot(x_trByYear_N1, y_trByYear_N, 'bs', alpha=0.4, label='train data');
    plt.plot(x_vaByYear_T1, y_vaByYear_T, 'cs', alpha=0.4, label='valid data');

    x_test_2 = [x_vaByYear_T1.min() + 2, x_vaByYear_T1.max() + 2]
    plt.fill_between(x_test_2, 0, 30, color='y', alpha=0.2, label='test period')

    L = 101
    xgrid_L1 = np.linspace(-5, 6, L).reshape((L,1))
    plt.plot(xgrid_L1, model.predict(xgrid_L1), 'r-', linewidth=3, label=model_legend_text);

    plt.ylim([0, 26]);
    plt.xlabel('Fractional Years since 1985');
    plt.ylabel("Min Daily Temp (deg C)");
    plt.legend(bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# # Problem 4: Linear Kernel Regression Baseline

# %% [markdown]
# ### Load kernel function from your completed `linear_kernel.py` file

# %%
import linear_kernel
from sklearn.model_selection import GridSearchCV
importlib.reload(linear_kernel)
# Out:
# <module 'linear_kernel' from '/content/linear_kernel.py'>

# %%
# Test call your function to verify you loaded the module correctly
# !python3 -m doctest  '/content/linear_kernel.py'

# %% [markdown]
# ### Establish a pipeline for LInear Kernel Regression
#
# Makes use of sklearn's `FunctionTransformer` (see [docs](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html)), which will apply kernel function as first 'transformation' step in our pipeline.
#
# What happens when we call `fit(x_train_NF)` with this pipeline?
#
# * 1) Transforms input features `x_train_NF` to kernel features `k_NN`
# * * Entry i,j is the kernel between the i-th training feature and j-th training feature
#
# * 2) Learns regression weight coefficient for each of the N columns of `k_NN`, by minimizing least squares objective with ridge penalty
#
# $$
# \min_{w \in \mathbb{R}^N, b} ~~ \sum_{n=1}^N (y_n - b - {\textstyle \sum_{i=1}^N w_i k(x_n, x_i)} )^2 ~ + \alpha \sum_{i=1}^N w_i^2
# $$
#
# What happens when we call `predict(x_QF)` with this pipeline?
#
# * 1) Transform input features x_QF to the kernel features k_QN
# * * Entry q,n is the kernel between the q-th test feature and n-th training feature
#
# * 2) Apply the learned ridge regression to the k_QN 'kernel features'
# * * Uses the learned weight coefficients for each of the N training examples

# %%
klr = sklearn.pipeline.Pipeline([
    ('linearkernelTransformer',
         sklearn.preprocessing.FunctionTransformer(calc_linear_kernel)), #TODO: use linear kernel
    ('ridgeRegressor', sklearn.linear_model.Ridge(alpha=1.0)),
    ])

# %% [markdown]
# ### Setup grid search for Problem 4
#
# Performance metric:
#
# * `neg_mean_squared_error` (uses sklearn's built-in mean squared error metric, with negative sign to follow "higher is better" convention)
#
# Hyperparameters to search:
#
# * `alpha` penalty for RidgeRegression (larger values mean larger strength penalty on sum-of-squares of weights)

# %%
klr_param_grid_by_name = dict(
    linearkernelTransformer__kw_args=[dict(x_train_NF=x_trByYear_N1)],
    ridgeRegressor__alpha=np.logspace(-10, 10, 5),
    )

# %%
from sklearn.model_selection import GridSearchCV
klr_grid_searcher = sklearn.model_selection.GridSearchCV(
    klr,
    klr_param_grid_by_name,
    scoring='neg_mean_squared_error',
    cv=my_ByYear_splitter,
    return_train_score=True,
    refit=False,
    )

# %% [markdown]
# ### Run the grid search

# %%
start_time_sec = time.time()
klr_grid_searcher.fit(x_all_ByYear_L1, y_all_ByYear_L)
elapsed_time_sec = time.time() - start_time_sec

# Build dataframe of results
klr_search_results_df = pd.DataFrame(klr_grid_searcher.cv_results_).copy()
print("Grid search of %3d configurations done after %6.1f sec" % (
    klr_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of   5 configurations done after  146.7 sec

# %% [markdown]
# ### Display search results

# %%
pd.set_option('display.precision', 4)
klr_param_keys = ['param_ridgeRegressor__alpha']
klr_search_results_df[klr_param_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']]
# Out:
#   param_ridgeRegressor__alpha  mean_train_score  mean_test_score  \
# 0                         0.0          -17.1946         -15.3344
# 1                         0.0          -17.1946         -15.3344
# 2                         1.0          -17.1946         -15.3344
# 3                    100000.0          -17.1946         -15.3311
# 4               10000000000.0          -17.3079         -14.0498
#
#    rank_test_score  mean_fit_time
# 0                3        20.6180
# 1                5        15.0828
# 2                4        12.4010
# 3                2        12.8216
# 4                1        10.4680

# %%
best_alpha = klr_search_results_df['param_ridgeRegressor__alpha'][klr_search_results_df['rank_test_score']==1].iloc[0]
print(f"Best alpha for linear kernel + ridge regression model: {best_alpha} ")
# Out:
# Best alpha for linear kernel + ridge regression model: 10000000000.0

# %% [markdown]
# ### Refit model with best hyperparameters on ALL development data (train+valid)

# %%
# Call klr.set_params(...) so that you are using the best hyperparameters found by grid search
best_params = klr_grid_searcher.best_params_
print(best_params)
klr.set_params(linearkernelTransformer__kw_args = dict(x_train_NF = x_all_ByYear_L1), ridgeRegressor__alpha = best_params['ridgeRegressor__alpha'])
# Out:
# {'linearkernelTransformer__kw_args': {'x_train_NF': array([[-4.00273973],
#        [-4.        ],
#        [-3.99726027],
#        ...,
#        [ 1.99178082],
#        [ 1.99452055],
#        [ 1.99726027]])}, 'ridgeRegressor__alpha': 10000000000.0}
# Pipeline(steps=[('linearkernelTransformer',
#                  FunctionTransformer(func=<function calc_linear_kernel at 0x7a17fe6e3910>,
#                                      kw_args={'x_train_NF': array([[-4.00273973],
#        [-4.        ],
#        [-3.99726027],
#        ...,
#        [ 3.99178082],
#        [ 3.99452055],
#        [ 3.99726027]])})),
#                 ('ridgeRegressor', Ridge(alpha=10000000000.0))])

# %%
klr.fit(x_all_ByYear_L1, y_all_ByYear_L);

# %% [markdown]
# ### Make Figure 4: predictions and data side-by-side

# %%
plot_data_and_predictions(klr, 'Linear Kernel Line')

# %% [markdown]
# # Problem 5: Squared Exponential Kernel Regression

# %%
import sqexp_kernel
# Allow any simultaneous edits to sqexp_kernel.py
# to be reloaded again into this notebook when this cell is executed
importlib.reload(sqexp_kernel)
# Out:
# <module 'sqexp_kernel' from '/content/sqexp_kernel.py'>

# %%
# !python3 -m doctest  '/content/sqxp_kernel.py'
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3.10/doctest.py", line 2810, in <module>
#     sys.exit(_test())
#   File "/usr/lib/python3.10/doctest.py", line 2798, in _test
#     m = __import__(filename[:-3])
# ModuleNotFoundError: No module named 'sqxp_kernel'

# %% [markdown]
# ### Establish a pipeline for SqExp Kernel Regression
#
# Again, makes use of sklearn's `FunctionTransformer` (see [docs](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html)), which will apply our `calc_sqexp_kernel` kernel function as first 'transformation' step in our pipeline.

# %%
sqexp_klr = sklearn.pipeline.Pipeline([
    ('sqexpKernelTransformer',
        sklearn.preprocessing.FunctionTransformer(calc_sqexp_kernel)), #Use squared-exponential kernel
    ('ridgeRegressor', sklearn.linear_model.Ridge(alpha=1.0)),
    ])

# %% [markdown]
# ### Setup grid search for SqExp Kernel hyperparameters

# %%
length_scale_grid = np.logspace(-2, 0, 9)
alpha_grid = np.logspace(-2, 3, 5)

print("Possible Values for sqexpKernelTransformer__kw_args['length_scale']")
for length_scale in length_scale_grid:
    print("% 11.3f" % length_scale)

print("Possible Values for ridgeRegressor__alpha")
for alpha in alpha_grid:
    print("% 11.3f" % alpha)
# Out:
# Possible Values for sqexpKernelTransformer__kw_args['length_scale']
#       0.010
#       0.018
#       0.032
#       0.056
#       0.100
#       0.178
#       0.316
#       0.562
#       1.000
# Possible Values for ridgeRegressor__alpha
#       0.010
#       0.178
#       3.162
#      56.234
#    1000.000

# %%
# Create dictionary where:
# each key is a pipeline parameter name
# each value is a grid of possible values
sqexp_param_grid_by_name = dict(
    sqexpKernelTransformer__kw_args=[dict(
        length_scale=ell,
        x_train_NF=x_trByYear_N1,
        ) for ell in length_scale_grid],
    ridgeRegressor__alpha=alpha_grid,
    )

# %%
# Package up into a sklearn GridSearch object

sqexp_klr_grid_searcher = sklearn.model_selection.GridSearchCV(
    sqexp_klr,
    sqexp_param_grid_by_name,
    scoring='neg_mean_squared_error',
    cv=my_ByYear_splitter,
    return_train_score=True,
    refit=False)

# %% [markdown]
# ### Run grid search: find hyperparameters that yield best heldout predictions

# %%
start_time_sec = time.time()
sqexp_klr_grid_searcher.fit(x_all_ByYear_L1, y_all_ByYear_L)
elapsed_time_sec = time.time() - start_time_sec

# Build dataframe of results
sqexp_klr_search_results_df = pd.DataFrame(sqexp_klr_grid_searcher.cv_results_).copy()
print("Grid search of %3d configurations done after %6.1f sec" % (
    sqexp_klr_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  45 configurations done after 2781.6 sec

# %%
pd.set_option('display.precision', 4)
param_keys = ['param_ridgeRegressor__alpha', 'param_sqexpKernelTransformer__kw_args']
sqexp_klr_search_results_df[param_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']]
# Out:
#    param_ridgeRegressor__alpha  \
# 0                         0.01
# 1                         0.01
# 2                         0.01
# 3                         0.01
# 4                         0.01
# 5                         0.01
# 6                         0.01
# 7                         0.01
# 8                         0.01
# 9                       0.1778
# 10                      0.1778
# 11                      0.1778
# 12                      0.1778
# 13                      0.1778
# 14                      0.1778
# 15                      0.1778
# 16                      0.1778
# 17                      0.1778
# 18                      3.1623
# 19                      3.1623
# 20                      3.1623
# 21                      3.1623
# 22                      3.1623
# 23                      3.1623
# 24                      3.1623
# 25                      3.1623
# 26                      3.1623
# 27                     56.2341
# 28                     56.2341
# 29                     56.2341
# 30                     56.2341
# 31                     56.2341
# 32                     56.2341
# 33                     56.2341
# 34                     56.2341
# 35                     56.2341
# 36                      1000.0
# 37                      1000.0
# 38                      1000.0
# 39                      1000.0
# 40                      1000.0
# 41                      1000.0
# 42                      1000.0
# 43                      1000.0
# 44                      1000.0
#
#                 param_sqexpKernelTransformer__kw_args  mean_train_score  \
# 0   {'length_scale': 0.01, 'x_train_NF': [[-4.0027...           -2.4462
# 1   {'length_scale': 0.01778279410038923, 'x_train...           -4.0045
# 2   {'length_scale': 0.03162277660168379, 'x_train...           -5.1109
# 3   {'length_scale': 0.05623413251903491, 'x_train...           -5.9347
# 4   {'length_scale': 0.1, 'x_train_NF': [[-4.00273...           -6.6137
# 5   {'length_scale': 0.1778279410038923, 'x_train_...           -6.9695
# 6   {'length_scale': 0.31622776601683794, 'x_train...           -7.2941
# 7   {'length_scale': 0.5623413251903491, 'x_train_...           -7.6100
# 8   {'length_scale': 1.0, 'x_train_NF': [[-4.00273...          -11.2152
# 9   {'length_scale': 0.01, 'x_train_NF': [[-4.0027...           -3.0070
# 10  {'length_scale': 0.01778279410038923, 'x_train...           -4.4456
# 11  {'length_scale': 0.03162277660168379, 'x_train...           -5.3795
# 12  {'length_scale': 0.05623413251903491, 'x_train...           -6.1629
# 13  {'length_scale': 0.1, 'x_train_NF': [[-4.00273...           -6.6692
# 14  {'length_scale': 0.1778279410038923, 'x_train_...           -7.0589
# 15  {'length_scale': 0.31622776601683794, 'x_train...           -7.3151
# 16  {'length_scale': 0.5623413251903491, 'x_train_...           -7.6551
# 17  {'length_scale': 1.0, 'x_train_NF': [[-4.00273...          -13.5359
# 18  {'length_scale': 0.01, 'x_train_NF': [[-4.0027...           -4.0424
# 19  {'length_scale': 0.01778279410038923, 'x_train...           -4.9479
# 20  {'length_scale': 0.03162277660168379, 'x_train...           -5.6947
# 21  {'length_scale': 0.05623413251903491, 'x_train...           -6.4394
# 22  {'length_scale': 0.1, 'x_train_NF': [[-4.00273...           -6.7857
# 23  {'length_scale': 0.1778279410038923, 'x_train_...           -7.1658
# 24  {'length_scale': 0.31622776601683794, 'x_train...           -7.3423
# 25  {'length_scale': 0.5623413251903491, 'x_train_...           -7.6834
# 26  {'length_scale': 1.0, 'x_train_NF': [[-4.00273...          -14.7018
# 27  {'length_scale': 0.01, 'x_train_NF': [[-4.0027...           -9.1880
# 28  {'length_scale': 0.01778279410038923, 'x_train...           -6.7965
# 29  {'length_scale': 0.03162277660168379, 'x_train...           -6.4071
# 30  {'length_scale': 0.05623413251903491, 'x_train...           -6.6811
# 31  {'length_scale': 0.1, 'x_train_NF': [[-4.00273...           -6.9594
# 32  {'length_scale': 0.1778279410038923, 'x_train_...           -7.2631
# 33  {'length_scale': 0.31622776601683794, 'x_train...           -7.4735
# 34  {'length_scale': 0.5623413251903491, 'x_train_...           -8.0447
# 35  {'length_scale': 1.0, 'x_train_NF': [[-4.00273...          -15.9491
# 36  {'length_scale': 0.01, 'x_train_NF': [[-4.0027...          -16.3884
# 37  {'length_scale': 0.01778279410038923, 'x_train...          -14.9075
# 38  {'length_scale': 0.03162277660168379, 'x_train...          -12.1012
# 39  {'length_scale': 0.05623413251903491, 'x_train...           -9.1288
# 40  {'length_scale': 0.1, 'x_train_NF': [[-4.00273...           -7.7998
# 41  {'length_scale': 0.1778279410038923, 'x_train_...           -7.5879
# 42  {'length_scale': 0.31622776601683794, 'x_train...           -7.9155
# 43  {'length_scale': 0.5623413251903491, 'x_train_...          -12.7464
# 44  {'length_scale': 1.0, 'x_train_NF': [[-4.00273...          -16.7281
#
#     mean_test_score  rank_test_score  mean_fit_time
# 0          -13.8860                9        29.2387
# 1          -18.7651               28        27.4418
# 2          -50.3175               35        28.9138
# 3         -139.8371               38        27.6897
# 4          -15.3757               27        26.8309
# 5         -207.0952               40        26.8635
# 6         -163.2736               39        26.7028
# 7        -1728.5618               43        26.8722
# 8        -1359.2168               42        26.3589
# 9          -13.9237               12        28.8133
# 10         -13.8118                7        28.0599
# 11         -14.2920               22        28.2456
# 12         -20.0032               29        28.7074
# 13         -30.9657               34        26.9143
# 14         -14.1906               21        25.8374
# 15         -28.0557               32        25.5338
# 16         -51.4045               36        26.2859
# 17      -20776.0161               45        25.7645
# 18         -13.9964               15        27.7591
# 19         -13.9181               11        28.8596
# 20         -13.8007                6        27.2258
# 21         -13.7903                5        25.3782
# 22         -14.5482               24        25.3546
# 23         -13.6663                1        25.4352
# 24         -14.8376               25        25.8226
# 25         -20.4609               30        25.0627
# 26       -4394.4238               44        24.6234
# 27         -14.0335               18        28.2459
# 28         -14.0036               16        28.3720
# 29         -13.9591               13        27.2658
# 30         -13.8862               10        26.4821
# 31         -13.7805                3        26.2816
# 32         -13.7848                4        27.4983
# 33         -15.1810               26        26.0784
# 34         -81.0839               37        25.3935
# 35        -363.2798               41        24.4275
# 36         -14.0450               20        27.5460
# 37         -14.0414               19        30.1463
# 38         -14.0298               17        27.1658
# 39         -13.9894               14        27.7558
# 40         -13.8848                8        27.0079
# 41         -13.7255                2        28.2735
# 42         -14.3233               23        24.6263
# 43         -29.4999               33        25.0931
# 44         -22.1841               31        25.6603

# %% [markdown]
# ### Determine the best hyperparameters

# %%
best_row = sqexp_klr_search_results_df['rank_test_score'].argmin()
best_param_df_row = sqexp_klr_search_results_df.loc[best_row][param_keys]

# Remove the "param_" prefix
sqexp_best_params = best_param_df_row.to_dict()
for key in list(sqexp_best_params.keys()):
    sqexp_best_params[key.replace('param_', '')] = sqexp_best_params[key]
    del sqexp_best_params[key]

# %%
print("Best Hyperparameters")
for k, v in sqexp_best_params.items():
    if isinstance(v, dict):
        for kk, vv in v.items():
            if kk.count('x_train'):
                continue
            print("%s %.5f" % (kk, vv))
    else:
        print("%s %.5f" % (k, v))
# Out:
# Best Hyperparameters
# ridgeRegressor__alpha 3.16228
# length_scale 0.17783

# %%
print("Best Results")
pd.DataFrame([sqexp_klr_search_results_df.loc[best_row, ['mean_train_score', 'mean_test_score', 'rank_test_score']]])
# Out:
# Best Results
#     mean_train_score  mean_test_score  rank_test_score
# 23           -7.1658         -13.6663                1

# %% [markdown]
# ### Refit model with best hyperparameters on ALL development data (train+valid)

# %%
# Create dictionary where:
# each key is a pipeline parameter name
# each value is a grid of possible values
sqexp_param_grid_by_name = dict(
    sqexpKernelTransformer__kw_args=[dict(
        length_scale=ell,
        x_train_NF=x_trByYear_N1,
        ) for ell in length_scale_grid],
    ridgeRegressor__alpha=alpha_grid,
    )

# %%
# Call sqexp_klr.set_params(...) so that you are using the best hyperparameters found by grid search
best_params = sqexp_klr_grid_searcher.best_params_
print(best_params)
sqexp_klr.set_params(
    sqexpKernelTransformer__kw_args=dict(
        length_scale=best_params['sqexpKernelTransformer__kw_args']['length_scale'],
        x_train_NF=x_all_ByYear_L1),

    ridgeRegressor__alpha=best_params['ridgeRegressor__alpha'],


    )
# Out:
# {'ridgeRegressor__alpha': 3.1622776601683795, 'sqexpKernelTransformer__kw_args': {'length_scale': 0.1778279410038923, 'x_train_NF': array([[-4.00273973],
#        [-4.        ],
#        [-3.99726027],
#        ...,
#        [ 1.99178082],
#        [ 1.99452055],
#        [ 1.99726027]])}}
# Pipeline(steps=[('sqexpKernelTransformer',
#                  FunctionTransformer(func=<function calc_sqexp_kernel at 0x7a17fbb640d0>,
#                                      kw_args={'length_scale': 0.1778279410038923,
#                                               'x_train_NF': array([[-4.00273973],
#        [-4.        ],
#        [-3.99726027],
#        ...,
#        [ 3.99178082],
#        [ 3.99452055],
#        [ 3.99726027]])})),
#                 ('ridgeRegressor', Ridge(alpha=3.1622776601683795))])

# %%
sqexp_klr.fit(x_all_ByYear_L1, y_all_ByYear_L);

# %% [markdown]
# ### Make Figure 5: Predictions of sq-exp kernel

# %%
plot_data_and_predictions(sqexp_klr, 'Sq-exp Kernel')

# %% [markdown]
# # Problem 6: Periodic kernel

# %%
import periodic_kernel

# Allow any simultaneous edits to periodic_kernel.py
# to be reloaded again into this notebook when this cell is executed
importlib.reload(periodic_kernel)
# Out:
# <module 'periodic_kernel' from '/content/periodic_kernel.py'>

# %%
periodic_klr = sklearn.pipeline.Pipeline([
    ('periodicKernelTransformer',
         sklearn.preprocessing.FunctionTransformer(calc_periodic_kernel)), #TODO: use periodic kernel
    ('ridgeRegressor', sklearn.linear_model.Ridge(alpha=1.0)),
    ])

# %% [markdown]
# ### Setup grid search for periodic kernel
#
# Don't need to change any values here!

# %%
periodic_grid = [0.5, 1.0, 1.5, 2.0]
length_scale_grid = [0.01, 0.03, 0.09, 0.27]
alpha_grid = [1.0, 1000.0, 100000.0]

print("Possible Values for periodicKernelTransformer__kw_args['periodic']")
for period in periodic_grid:
    print("% 11.3f" % period)

print("Possible Values for periodicKernelTransformer__kw_args['length_scale']")
for length_scale in length_scale_grid:
    print("% 11.3f" % length_scale)

print("Possible Values for ridgeRegressor__alpha")
for alpha in alpha_grid:
    print("% 11.3f" % alpha)
# Out:
# Possible Values for periodicKernelTransformer__kw_args['periodic']
#       0.500
#       1.000
#       1.500
#       2.000
# Possible Values for periodicKernelTransformer__kw_args['length_scale']
#       0.010
#       0.030
#       0.090
#       0.270
# Possible Values for ridgeRegressor__alpha
#       1.000
#    1000.000
#  100000.000

# %%
periodic_param_grid_by_name = dict(
    periodicKernelTransformer__kw_args=[
        dict(length_scale=ell, period=p,
            x_train_NF=x_trByYear_N1) for (ell,p) in itertools.product(length_scale_grid, periodic_grid)],
    ridgeRegressor__alpha=alpha_grid,
    )

# %%
periodic_klr_grid_searcher = sklearn.model_selection.GridSearchCV(
    periodic_klr,
    periodic_param_grid_by_name,
    scoring='neg_mean_squared_error',
    cv=my_ByYear_splitter,
    return_train_score=True,
    refit=False)

# %% [markdown]
# ### Run grid search for 'period' and 'length_scale' and 'alpha' hyperparameters

# %%
start_time_sec = time.time()
periodic_klr_grid_searcher.fit(x_all_ByYear_L1, y_all_ByYear_L)
elapsed_time_sec = time.time() - start_time_sec

# Build dataframe of results
periodic_klr_search_results_df = pd.DataFrame(periodic_klr_grid_searcher.cv_results_).copy()
print("Grid search of %3d configurations done after %6.1f sec" % (
    periodic_klr_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  48 configurations done after   78.9 sec

# %%
pd.set_option('display.precision', 4)
param_keys = ['param_ridgeRegressor__alpha', 'param_periodicKernelTransformer__kw_args']
periodic_klr_search_results_df[param_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']]
# Out:
#    param_ridgeRegressor__alpha  \
# 0                          1.0
# 1                       1000.0
# 2                     100000.0
# 3                          1.0
# 4                       1000.0
# 5                     100000.0
# 6                          1.0
# 7                       1000.0
# 8                     100000.0
# 9                          1.0
# 10                      1000.0
# 11                    100000.0
# 12                         1.0
# 13                      1000.0
# 14                    100000.0
# 15                         1.0
# 16                      1000.0
# 17                    100000.0
# 18                         1.0
# 19                      1000.0
# 20                    100000.0
# 21                         1.0
# 22                      1000.0
# 23                    100000.0
# 24                         1.0
# 25                      1000.0
# 26                    100000.0
# 27                         1.0
# 28                      1000.0
# 29                    100000.0
# 30                         1.0
# 31                      1000.0
# 32                    100000.0
# 33                         1.0
# 34                      1000.0
# 35                    100000.0
# 36                         1.0
# 37                      1000.0
# 38                    100000.0
# 39                         1.0
# 40                      1000.0
# 41                    100000.0
# 42                         1.0
# 43                      1000.0
# 44                    100000.0
# 45                         1.0
# 46                      1000.0
# 47                    100000.0
#
#              param_periodicKernelTransformer__kw_args  mean_train_score  \
# 0   {'length_scale': 0.01, 'period': 0.5, 'x_train...          -16.2827
# 1   {'length_scale': 0.01, 'period': 0.5, 'x_train...          -17.0025
# 2   {'length_scale': 0.01, 'period': 0.5, 'x_train...          -17.3049
# 3   {'length_scale': 0.01, 'period': 1.0, 'x_train...           -6.7734
# 4   {'length_scale': 0.01, 'period': 1.0, 'x_train...          -13.1545
# 5   {'length_scale': 0.01, 'period': 1.0, 'x_train...          -17.2484
# 6   {'length_scale': 0.01, 'period': 1.5, 'x_train...          -15.6510
# 7   {'length_scale': 0.01, 'period': 1.5, 'x_train...          -16.9135
# 8   {'length_scale': 0.01, 'period': 1.5, 'x_train...          -17.3038
# 9   {'length_scale': 0.01, 'period': 2.0, 'x_train...           -6.2176
# 10  {'length_scale': 0.01, 'period': 2.0, 'x_train...          -13.0834
# 11  {'length_scale': 0.01, 'period': 2.0, 'x_train...          -17.2474
# 12  {'length_scale': 0.03, 'period': 0.5, 'x_train...          -16.5254
# 13  {'length_scale': 0.03, 'period': 0.5, 'x_train...          -16.7571
# 14  {'length_scale': 0.03, 'period': 0.5, 'x_train...          -17.2838
# 15  {'length_scale': 0.03, 'period': 1.0, 'x_train...           -7.2176
# 16  {'length_scale': 0.03, 'period': 1.0, 'x_train...           -8.2128
# 17  {'length_scale': 0.03, 'period': 1.0, 'x_train...          -16.8000
# 18  {'length_scale': 0.03, 'period': 1.5, 'x_train...          -16.3311
# 19  {'length_scale': 0.03, 'period': 1.5, 'x_train...          -16.7296
# 20  {'length_scale': 0.03, 'period': 1.5, 'x_train...          -17.2831
# 21  {'length_scale': 0.03, 'period': 2.0, 'x_train...           -7.0019
# 22  {'length_scale': 0.03, 'period': 2.0, 'x_train...           -8.1487
# 23  {'length_scale': 0.03, 'period': 2.0, 'x_train...          -16.8028
# 24  {'length_scale': 0.09, 'period': 0.5, 'x_train...          -16.7695
# 25  {'length_scale': 0.09, 'period': 0.5, 'x_train...          -16.8664
# 26  {'length_scale': 0.09, 'period': 0.5, 'x_train...          -17.1972
# 27  {'length_scale': 0.09, 'period': 1.0, 'x_train...           -7.5673
# 28  {'length_scale': 0.09, 'period': 1.0, 'x_train...           -7.7131
# 29  {'length_scale': 0.09, 'period': 1.0, 'x_train...          -13.9671
# 30  {'length_scale': 0.09, 'period': 1.5, 'x_train...          -16.7510
# 31  {'length_scale': 0.09, 'period': 1.5, 'x_train...          -16.8452
# 32  {'length_scale': 0.09, 'period': 1.5, 'x_train...          -17.2085
# 33  {'length_scale': 0.09, 'period': 2.0, 'x_train...           -7.5768
# 34  {'length_scale': 0.09, 'period': 2.0, 'x_train...           -7.6486
# 35  {'length_scale': 0.09, 'period': 2.0, 'x_train...          -14.1948
# 36  {'length_scale': 0.27, 'period': 0.5, 'x_train...          -16.9578
# 37  {'length_scale': 0.27, 'period': 0.5, 'x_train...          -17.0109
# 38  {'length_scale': 0.27, 'period': 0.5, 'x_train...          -17.0743
# 39  {'length_scale': 0.27, 'period': 1.0, 'x_train...           -7.7535
# 40  {'length_scale': 0.27, 'period': 1.0, 'x_train...           -7.7703
# 41  {'length_scale': 0.27, 'period': 1.0, 'x_train...           -9.1615
# 42  {'length_scale': 0.27, 'period': 1.5, 'x_train...          -16.9313
# 43  {'length_scale': 0.27, 'period': 1.5, 'x_train...          -17.0109
# 44  {'length_scale': 0.27, 'period': 1.5, 'x_train...          -17.2306
# 45  {'length_scale': 0.27, 'period': 2.0, 'x_train...           -7.7037
# 46  {'length_scale': 0.27, 'period': 2.0, 'x_train...           -7.7580
# 47  {'length_scale': 0.27, 'period': 2.0, 'x_train...          -11.4451
#
#     mean_test_score  rank_test_score  mean_fit_time
# 0          -14.7504               48         1.0584
# 1          -14.0620               38         1.6758
# 2          -14.0458               35         1.7536
# 3           -8.9610               13         1.2793
# 4          -10.9931               17         1.1294
# 5          -13.9993               30         1.0273
# 6          -14.7104               47         1.0633
# 7          -13.9929               26         1.0236
# 8          -14.0448               34         1.0355
# 9          -10.0576               16         1.0394
# 10         -11.1285               18         1.7199
# 11         -14.0010               31         1.7337
# 12         -14.6996               46         1.0249
# 13         -14.3375               41         1.0268
# 14         -14.0475               36         1.0216
# 15          -8.7583               12         1.0285
# 16          -7.9869                1         0.9940
# 17         -13.6415               21         1.0343
# 18         -14.6311               44         1.0507
# 19         -13.9616               25         1.6942
# 20         -14.0340               32         1.6826
# 21          -9.5305               14         1.2650
# 22          -8.2617                7         1.0267
# 23         -13.6541               22         1.0085
# 24         -14.6524               45         1.0136
# 25         -14.4594               43         1.0103
# 26         -14.0552               37         0.9904
# 27          -8.4125                9         1.0433
# 28          -7.9928                2         1.2625
# 29         -11.3934               19         1.6050
# 30         -13.9992               29         1.6572
# 31         -13.9358               24         1.0052
# 32         -13.9945               27         0.9887
# 33          -8.6661               11         1.0523
# 34          -8.3471                8         1.0174
# 35         -11.6271               20         1.0008
# 36         -14.3982               42         1.0315
# 37         -14.2827               40         1.0484
# 38         -14.1181               39         1.6825
# 39          -8.1067                5         1.6911
# 40          -8.0444                4         1.0536
# 41          -8.0112                3         1.0664
# 42         -14.0367               33         1.0311
# 43         -13.9971               28         1.0468
# 44         -13.9249               23         0.9951
# 45          -8.4247               10         1.0022
# 46          -8.2266                6         1.0034
# 47          -9.6065               15         1.5519

# %% [markdown]
# ### Determine the best hyperparameters

# %%
best_row = periodic_klr_search_results_df['rank_test_score'].argmin()
best_param_df_row = periodic_klr_search_results_df.loc[best_row][param_keys]

best_params = best_param_df_row.to_dict()
for key in list(best_params.keys()):
    best_params[key.replace('param_', '')] = best_params[key]
    del best_params[key]

# %%
print("Best Hyperparameters")
for k, v in best_params.items():
    if isinstance(v, dict):
        for kk, vv in v.items():
            if kk.count('x_train'):
                continue
            print("%s['%s'] %.3f" % (k, kk, vv))
    else:
        print("%s %.3f" % (k, v))
# Out:
# Best Hyperparameters
# ridgeRegressor__alpha 1000.000
# periodicKernelTransformer__kw_args['length_scale'] 0.030
# periodicKernelTransformer__kw_args['period'] 1.000

# %% [markdown]
# ### Determine the performance results associated with these best hyperparameters

# %%
print("Best Results")
pd.DataFrame([periodic_klr_search_results_df.loc[best_row, ['mean_train_score', 'mean_test_score', 'rank_test_score']]])
# Out:
# Best Results
#     mean_train_score  mean_test_score  rank_test_score
# 16           -8.2128          -7.9869                1

# %% [markdown]
# ### Retrain model with best hyperparameters on ALL development data

# %%
periodic_param_grid_by_name = dict(
    periodicKernelTransformer__kw_args=[
        dict(length_scale=0.030, period=1.000,
            x_train_NF=x_all_ByYear_L1) for (ell,p) in itertools.product(length_scale_grid, periodic_grid)],
    ridgeRegressor__alpha=1000.000,
    )

# %%
# Call periodic_klr.set_params(...) so that you are using the best hyperparameters found by grid search
best_params = periodic_klr_grid_searcher.best_params_
print(best_params)
periodic_klr.set_params(periodicKernelTransformer__kw_args =
        dict(length_scale = best_params['periodicKernelTransformer__kw_args']['length_scale'],
             period = best_params['periodicKernelTransformer__kw_args']['period'],
             x_train_NF=x_all_ByYear_L1
        ),
        ridgeRegressor__alpha= best_params['ridgeRegressor__alpha'])
# Out:
# {'periodicKernelTransformer__kw_args': {'length_scale': 0.03, 'period': 1.0, 'x_train_NF': array([[-4.00273973],
#        [-4.        ],
#        [-3.99726027],
#        ...,
#        [ 1.99178082],
#        [ 1.99452055],
#        [ 1.99726027]])}, 'ridgeRegressor__alpha': 1000.0}
# Pipeline(steps=[('periodicKernelTransformer',
#                  FunctionTransformer(func=<function calc_periodic_kernel at 0x7a17fbb64160>,
#                                      kw_args={'length_scale': 0.03,
#                                               'period': 1.0,
#                                               'x_train_NF': array([[-4.00273973],
#        [-4.        ],
#        [-3.99726027],
#        ...,
#        [ 3.99178082],
#        [ 3.99452055],
#        [ 3.99726027]])})),
#                 ('ridgeRegressor', Ridge(alpha=1000.0))])

# %%
periodic_klr.fit(x_all_ByYear_L1, y_all_ByYear_L);

# %% [markdown]
# ### Make Fig 6: Predictions of periodic kernel

# %%
plot_data_and_predictions(periodic_klr, 'Periodic Kernel')

# %% [markdown]
# # Problem 7
#
# ### Load test data

# %%
data_te_df = pd.read_csv(os.path.join(DATA_DIR, 'data_test_ByYear.csv'))
x_te_T1 = data_te_df['years_since_19850101'].values[:][:,np.newaxis].copy()  # Load (T,1) feature values array
y_te_T = data_te_df['temp_deg_C'].values[:].copy()                           # Load (T,) feature values array

# %%
row_dict_list = list()
for (split, x, y) in [
        ('train+valid', x_all_ByYear_L1, y_all_ByYear_L),
        ('test', x_te_T1, y_te_T)
        ]:
    for (method_name, predictor) in [
            ('linear kernel', klr),
            ('sqexp kernel', sqexp_klr),
            ('periodic kernel', periodic_klr),
            ]:

        yhat = predictor.predict(x)

        rmse = np.sqrt(np.mean(np.square(yhat - y)))
        row_dict = dict(method=method_name, rmse=rmse, split=split)
        row_dict_list.append(row_dict)

# %%
df = pd.DataFrame(row_dict_list)

# %%
df
# Out:
#             method    rmse        split
# 0    linear kernel  4.0599  train+valid
# 1     sqexp kernel  2.6605  train+valid
# 2  periodic kernel  2.8029  train+valid
# 3    linear kernel  4.1198         test
# 4     sqexp kernel  4.0025         test
# 5  periodic kernel  2.6756         test

# %% [markdown]
# ## Create Table 7

# %%
pd.set_option('display.precision', 2); # please report only 2 digits of precision after decimal for RMSE
tab_df = pd.pivot_table(df,
    values='rmse',
    index=['method'],
    columns=['split'],
    aggfunc=np.sum)\
    .reindex(['train+valid', 'test'], axis=1)\
    .reindex(['linear kernel', 'sqexp kernel', 'periodic kernel'])

# %%
tab_df # Pretty print to this notebook
# Out:
# split            train+valid  test
# method
# linear kernel           4.06  4.12
# sqexp kernel            2.66  4.00
# periodic kernel         2.80  2.68
