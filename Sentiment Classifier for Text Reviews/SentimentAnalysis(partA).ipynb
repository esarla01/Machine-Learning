# %% [markdown]
# # Sentiment Analysis (PART A)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd

import sklearn.linear_model
import sklearn.pipeline
from sklearn.utils import shuffle

# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# ### Load Training Data

# %%
import numpy as np
import pandas as pd
import os

data_dir = 'data_reviews'
x_train_df = pd.read_csv(os.path.join(data_dir, 'x_train.csv'))
y_train_df = pd.read_csv(os.path.join(data_dir, 'y_train.csv'))
x_test_df = pd.read_csv(os.path.join(data_dir, 'x_test.csv'))
our_test_x_df = pd.read_csv(os.path.join(data_dir, 'our_test_x.csv'))
our_test_y_df = pd.read_csv(os.path.join(data_dir, 'our_test_y.csv'))

# %% [markdown]
# ### Changing text format (df to np)

# %%
text_col_arr =  x_train_df['text'].values
results_col_arr = np.ravel(y_train_df.values)

# %% [markdown]
# ### Building a Custom Preprocessor

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Prepare a custom preprocessor to remove numbers
def custom_preprocessor(text):
  words = text.split()
  cleaned_words = []

  for word in words:
    cleaned_word = ''

    for char in word:
      if not char.isdigit():
        cleaned_word += char

    cleaned_words.append(cleaned_word)

  cleaned_text = " ". join(cleaned_words)
  return cleaned_text

def combined_preprocessor(text):
  text = CountVectorizer().build_preprocessor()(text)
  text = custom_preprocessor(text)
  return text

# %% [markdown]
# ### Bag-of-Words Extraction

# %%
# CountVectorizer configuration to analyze token frequencies
count_vectorizer = CountVectorizer(
    preprocessor=combined_preprocessor,
    min_df=1,  # Minimum document frequency
    max_df=1.0,  # Maximum document frequency
    ngram_range=(1, 1)  # N-gram range
)

# Fit and transform the text data using CountVectorizer
document_term_matrix = count_vectorizer.fit_transform(text_col_arr)

# Calculate the document frequency for each token
total_document_frequency = document_term_matrix.sum(axis=0)

# Convert the document frequency matrix to a list
document_frequency_list = total_document_frequency.tolist()[0]

# Create a dictionary mapping tokens to their document frequency
token_document_frequency_dict = dict(zip(count_vectorizer.get_feature_names_out(), document_frequency_list))

# Print the total number of tokens
total_tokens = len(token_document_frequency_dict)
print(f"Total Tokens: {total_tokens}")

# Print the document frequency for each token
for token, document_frequency in token_document_frequency_dict.items():
    print(f"Token: {token}, Document Frequency: {document_frequency}")
# Out:
# Total Tokens: 4439
# Token: abandoned, Document Frequency: 1
# Token: abhor, Document Frequency: 1
# Token: ability, Document Frequency: 4
# Token: able, Document Frequency: 4
# Token: abound, Document Frequency: 1
# Token: about, Document Frequency: 70
# Token: above, Document Frequency: 6
# Token: abroad, Document Frequency: 1
# Token: absolute, Document Frequency: 1
# Token: absolutel, Document Frequency: 1
# Token: absolutely, Document Frequency: 18
# Token: absolutley, Document Frequency: 1
# Token: abstruse, Document Frequency: 1
# Token: abysmal, Document Frequency: 1
# Token: ac, Document Frequency: 1
# Token: academy, Document Frequency: 1
# Token: accents, Document Frequency: 1
# Token: accept, Document Frequency: 1
# Token: acceptable, Document Frequency: 1
# Token: access, Document Frequency: 2
# Token: accessable, Document Frequency: 1
# Token: accessible, Document Frequency: 1
# Token: accessoryone, Document Frequency: 1
# Token: accident, Document Frequency: 1
# Token: accidentally, Document Frequency: 2
# Token: acclaimed, Document Frequency: 1
# Token: accolades, Document Frequency: 1
# Token: accomodate, Document Frequency: 1
# Token: accompanied, Document Frequency: 1
# Token: accurate, Document Frequency: 1
# Token: accurately, Document Frequency: 1
# Token: accused, Document Frequency: 2
# Token: ache, Document Frequency: 1
# Token: achievement, Document Frequency: 1
# Token: achille, Document Frequency: 1
# Token: ackerman, Document Frequency: 1
# Token: acknowledged, Document Frequency: 1
# Token: act, Document Frequency: 1
# Token: acted, Document Frequency: 2
# Token: acting, Document Frequency: 32
# Token: action, Document Frequency: 6
# Token: actions, Document Frequency: 1
# Token: activate, Document Frequency: 1
# Token: actor, Document Frequency: 7
# Token: actors, Document Frequency: 17
# Token: actress, Document Frequency: 2
# Token: actresses, Document Frequency: 2
# Token: actual, Document Frequency: 1
# Token: actually, Document Frequency: 14
# Token: ad, Document Frequency: 1
# Token: adaptation, Document Frequency: 2
# Token: adapter, Document Frequency: 1
# Token: adapters, Document Frequency: 1
# Token: add, Document Frequency: 1
# Token: added, Document Frequency: 1
# Token: addition, Document Frequency: 3
# Token: additional, Document Frequency: 1
# Token: adhesive, Document Frequency: 1
# Token: admins, Document Frequency: 1
# Token: admitted, Document Frequency: 1
# Token: adorable, Document Frequency: 4
# Token: adrift, Document Frequency: 1
# Token: adventure, Document Frequency: 1
# Token: advertised, Document Frequency: 2
# Token: advise, Document Frequency: 4
# Token: aerial, Document Frequency: 2
# Token: aesthetically, Document Frequency: 1
# Token: affected, Document Frequency: 1
# Token: affleck, Document Frequency: 1
# Token: affordable, Document Frequency: 1
# Token: afraid, Document Frequency: 1
# Token: africa, Document Frequency: 2
# Token: after, Document Frequency: 40
# Token: afternoon, Document Frequency: 2
# Token: again, Document Frequency: 40
# Token: against, Document Frequency: 1
# Token: age, Document Frequency: 4
# Token: aged, Document Frequency: 1
# Token: ages, Document Frequency: 1
# Token: ago, Document Frequency: 6
# Token: agreed, Document Frequency: 1
# Token: ahead, Document Frequency: 1
# Token: aimless, Document Frequency: 1
# Token: air, Document Frequency: 2
# Token: aired, Document Frequency: 1
# Token: airline, Document Frequency: 1
# Token: akin, Document Frequency: 1
# Token: ala, Document Frequency: 1
# Token: alarm, Document Frequency: 1
# Token: albondigas, Document Frequency: 1
# Token: alexander, Document Frequency: 1
# Token: alike, Document Frequency: 1
# Token: all, Document Frequency: 118
# Token: allot, Document Frequency: 1
# Token: allow, Document Frequency: 2
# Token: allowing, Document Frequency: 2
# Token: allows, Document Frequency: 2
# Token: almonds, Document Frequency: 1
# Token: almost, Document Frequency: 14
# Token: alone, Document Frequency: 1
# Token: along, Document Frequency: 2
# Token: alongside, Document Frequency: 1
# Token: alot, Document Frequency: 1
# Token: already, Document Frequency: 4
# Token: also, Document Frequency: 57
# Token: although, Document Frequency: 8
# Token: aluminum, Document Frequency: 1
# Token: always, Document Frequency: 16
# Token: am, Document Frequency: 27
# Token: amateurish, Document Frequency: 1
# Token: amaze, Document Frequency: 1
# Token: amazed, Document Frequency: 3
# Token: amazing, Document Frequency: 29
# Token: amazingly, Document Frequency: 1
# Token: amazon, Document Frequency: 6
# Token: ambiance, Document Frequency: 4
# Token: ambience, Document Frequency: 3
# Token: america, Document Frequency: 2
# Token: american, Document Frequency: 2
# Token: americans, Document Frequency: 1
# Token: among, Document Frequency: 2
# Token: amount, Document Frequency: 8
# Token: amp, Document Frequency: 1
# Token: ample, Document Frequency: 2
# Token: amusing, Document Frequency: 1
# Token: an, Document Frequency: 91
# Token: anatomist, Document Frequency: 1
# Token: and, Document Frequency: 926
# Token: andddd, Document Frequency: 1
# Token: angela, Document Frequency: 1
# Token: angeles, Document Frequency: 2
# Token: angelina, Document Frequency: 1
# Token: angle, Document Frequency: 2
# Token: angles, Document Frequency: 1
# Token: angry, Document Frequency: 1
# Token: angus, Document Frequency: 1
# Token: animals, Document Frequency: 1
# Token: animated, Document Frequency: 1
# Token: animation, Document Frequency: 3
# Token: anne, Document Frequency: 2
# Token: anniversary, Document Frequency: 1
# Token: annoying, Document Frequency: 5
# Token: another, Document Frequency: 18
# Token: answer, Document Frequency: 2
# Token: ant, Document Frequency: 1
# Token: antena, Document Frequency: 1
# Token: anthony, Document Frequency: 1
# Token: anti, Document Frequency: 1
# Token: anticipated, Document Frequency: 1
# Token: any, Document Frequency: 38
# Token: anymore, Document Frequency: 1
# Token: anyone, Document Frequency: 21
# Token: anything, Document Frequency: 13
# Token: anytime, Document Frequency: 5
# Token: anyway, Document Frequency: 3
# Token: anyways, Document Frequency: 1
# Token: anywhere, Document Frequency: 1
# Token: apart, Document Frequency: 2
# Token: apologize, Document Frequency: 1
# Token: apology, Document Frequency: 1
# Token: app, Document Frequency: 1
# Token: appalling, Document Frequency: 2
# Token: apparently, Document Frequency: 2
# Token: appealing, Document Frequency: 3
# Token: appearance, Document Frequency: 4
# Token: appears, Document Frequency: 3
# Token: appetite, Document Frequency: 1
# Token: appetizer, Document Frequency: 1
# Token: appetizers, Document Frequency: 2
# Token: applauded, Document Frequency: 1
# Token: applause, Document Frequency: 1
# Token: apple, Document Frequency: 1
# Token: appointments, Document Frequency: 1
# Token: appreciate, Document Frequency: 4
# Token: appropriate, Document Frequency: 1
# Token: approval, Document Frequency: 1
# Token: apt, Document Frequency: 1
# Token: are, Document Frequency: 143
# Token: area, Document Frequency: 7
# Token: aren, Document Frequency: 4
# Token: argued, Document Frequency: 1
# Token: aria, Document Frequency: 1
# Token: armageddon, Document Frequency: 1
# Token: armand, Document Frequency: 1
# Token: armband, Document Frequency: 1
# Token: around, Document Frequency: 19
# Token: array, Document Frequency: 1
# Token: arrival, Document Frequency: 1
# Token: arrived, Document Frequency: 7
# Token: arriving, Document Frequency: 1
# Token: art, Document Frequency: 11
# Token: article, Document Frequency: 1
# Token: articulated, Document Frequency: 1
# Token: artiness, Document Frequency: 1
# Token: artist, Document Frequency: 2
# Token: artless, Document Frequency: 1
# Token: arts, Document Frequency: 1
# Token: as, Document Frequency: 136
# Token: asia, Document Frequency: 1
# Token: aside, Document Frequency: 2
# Token: ask, Document Frequency: 5
# Token: asked, Document Frequency: 4
# Token: asleep, Document Frequency: 2
# Token: aspect, Document Frequency: 2
# Token: aspects, Document Frequency: 1
# Token: ass, Document Frequency: 2
# Token: assante, Document Frequency: 1
# Token: assaulted, Document Frequency: 1
# Token: assistant, Document Frequency: 2
# Token: assumed, Document Frequency: 1
# Token: assure, Document Frequency: 2
# Token: astonishingly, Document Frequency: 1
# Token: astronaut, Document Frequency: 2
# Token: at, Document Frequency: 106
# Token: ate, Document Frequency: 3
# Token: atleast, Document Frequency: 1
# Token: atmosphere, Document Frequency: 11
# Token: atrocious, Document Frequency: 2
# Token: att, Document Frequency: 2
# Token: attached, Document Frequency: 1
# Token: attack, Document Frequency: 2
# Token: attacked, Document Frequency: 1
# Token: attempt, Document Frequency: 3
# Token: attempted, Document Frequency: 1
# Token: attempting, Document Frequency: 1
# Token: attempts, Document Frequency: 2
# Token: attention, Document Frequency: 4
# Token: attentive, Document Frequency: 7
# Token: attitudes, Document Frequency: 2
# Token: attractive, Document Frequency: 2
# Token: audience, Document Frequency: 4
# Token: audio, Document Frequency: 7
# Token: auju, Document Frequency: 1
# Token: aurvåg, Document Frequency: 1
# Token: austen, Document Frequency: 1
# Token: austere, Document Frequency: 1
# Token: authentic, Document Frequency: 6
# Token: author, Document Frequency: 1
# Token: auto, Document Frequency: 2
# Token: available, Document Frequency: 1
# Token: average, Document Frequency: 5
# Token: avocado, Document Frequency: 1
# Token: avoid, Document Frequency: 10
# Token: avoided, Document Frequency: 2
# Token: avoiding, Document Frequency: 1
# Token: award, Document Frequency: 1
# Token: awards, Document Frequency: 1
# Token: away, Document Frequency: 12
# Token: awesome, Document Frequency: 16
# Token: awful, Document Frequency: 15
# Token: awkward, Document Frequency: 2
# Token: awkwardly, Document Frequency: 2
# Token: awsome, Document Frequency: 1
# Token: ayce, Document Frequency: 1
# Token: aye, Document Frequency: 1
# Token: az, Document Frequency: 1
# Token: baaaaaad, Document Frequency: 1
# Token: baba, Document Frequency: 1
# Token: babbling, Document Frequency: 1
# Token: babie, Document Frequency: 1
# Token: baby, Document Frequency: 1
# Token: bachi, Document Frequency: 1
# Token: back, Document Frequency: 62
# Token: backdrop, Document Frequency: 1
# Token: backed, Document Frequency: 1
# Token: background, Document Frequency: 2
# Token: backlight, Document Frequency: 1
# Token: bacon, Document Frequency: 4
# Token: bad, Document Frequency: 81
# Token: badly, Document Frequency: 2
# Token: bag, Document Frequency: 1
# Token: bagels, Document Frequency: 1
# Token: bailey, Document Frequency: 1
# Token: bakery, Document Frequency: 3
# Token: baklava, Document Frequency: 1
# Token: balance, Document Frequency: 2
# Token: balanced, Document Frequency: 1
# Token: ball, Document Frequency: 2
# Token: ballet, Document Frequency: 1
# Token: balls, Document Frequency: 1
# Token: bamboo, Document Frequency: 1
# Token: banana, Document Frequency: 1
# Token: band, Document Frequency: 1
# Token: bank, Document Frequency: 1
# Token: bar, Document Frequency: 8
# Token: barcelona, Document Frequency: 1
# Token: bare, Document Frequency: 1
# Token: barely, Document Frequency: 11
# Token: bargain, Document Frequency: 3
# Token: barking, Document Frequency: 1
# Token: barney, Document Frequency: 1
# Token: barren, Document Frequency: 1
# Token: bars, Document Frequency: 5
# Token: bartender, Document Frequency: 2
# Token: bartenders, Document Frequency: 1
# Token: baseball, Document Frequency: 1
# Token: based, Document Frequency: 2
# Token: basement, Document Frequency: 1
# Token: basic, Document Frequency: 2
# Token: basically, Document Frequency: 5
# Token: bat, Document Frequency: 1
# Token: bates, Document Frequency: 1
# Token: bathroom, Document Frequency: 3
# Token: bathrooms, Document Frequency: 2
# Token: batter, Document Frequency: 2
# Token: batteries, Document Frequency: 2
# Token: battery, Document Frequency: 34
# Token: baxendale, Document Frequency: 1
# Token: bay, Document Frequency: 2
# Token: bbq, Document Frequency: 1
# Token: be, Document Frequency: 120
# Token: bean, Document Frequency: 1
# Token: beans, Document Frequency: 3
# Token: bear, Document Frequency: 2
# Token: beat, Document Frequency: 4
# Token: beateous, Document Frequency: 1
# Token: beats, Document Frequency: 1
# Token: beautiful, Document Frequency: 14
# Token: beautifully, Document Frequency: 3
# Token: beauty, Document Frequency: 1
# Token: became, Document Frequency: 2
# Token: because, Document Frequency: 47
# Token: bechard, Document Frequency: 1
# Token: become, Document Frequency: 3
# Token: becomes, Document Frequency: 1
# Token: bed, Document Frequency: 1
# Token: beef, Document Frequency: 5
# Token: been, Document Frequency: 42
# Token: beep, Document Frequency: 3
# Token: beeping, Document Frequency: 1
# Token: beer, Document Frequency: 5
# Token: before, Document Frequency: 15
# Token: began, Document Frequency: 1
# Token: begin, Document Frequency: 2
# Token: beginning, Document Frequency: 4
# Token: behind, Document Frequency: 3
# Token: behing, Document Frequency: 1
# Token: behold, Document Frequency: 1
# Token: being, Document Frequency: 29
# Token: bela, Document Frequency: 1
# Token: believable, Document Frequency: 6
# Token: believe, Document Frequency: 9
# Token: bell, Document Frequency: 1
# Token: bellagio, Document Frequency: 1
# Token: bellies, Document Frequency: 1
# Token: bells, Document Frequency: 1
# Token: bellucci, Document Frequency: 1
# Token: belly, Document Frequency: 3
# Token: belmondo, Document Frequency: 1
# Token: below, Document Frequency: 4
# Token: belt, Document Frequency: 5
# Token: ben, Document Frequency: 1
# Token: bend, Document Frequency: 1
# Token: bendingly, Document Frequency: 1
# Token: bennett, Document Frequency: 1
# Token: bergen, Document Frequency: 1
# Token: bertolucci, Document Frequency: 1
# Token: besides, Document Frequency: 1
# Token: best, Document Frequency: 63
# Token: better, Document Frequency: 46
# Token: between, Document Frequency: 14
# Token: beware, Document Frequency: 2
# Token: beyond, Document Frequency: 4
# Token: bible, Document Frequency: 1
# Token: big, Document Frequency: 17
# Token: bigger, Document Frequency: 1
# Token: biggest, Document Frequency: 2
# Token: bill, Document Frequency: 1
# Token: bills, Document Frequency: 1
# Token: billy, Document Frequency: 3
# Token: binge, Document Frequency: 1
# Token: bipolarity, Document Frequency: 1
# Token: bird, Document Frequency: 1
# Token: biscuit, Document Frequency: 1
# Token: biscuits, Document Frequency: 2
# Token: bit, Document Frequency: 11
# Token: bitches, Document Frequency: 1
# Token: bitchy, Document Frequency: 1
# Token: bite, Document Frequency: 2
# Token: bites, Document Frequency: 1
# Token: bitpim, Document Frequency: 1
# Token: black, Document Frequency: 14
# Token: blackberry, Document Frequency: 2
# Token: blacktop, Document Frequency: 1
# Token: blah, Document Frequency: 2
# Token: blake, Document Frequency: 1
# Token: blame, Document Frequency: 1
# Token: bland, Document Frequency: 11
# Token: blandest, Document Frequency: 1
# Token: blandly, Document Frequency: 1
# Token: blare, Document Frequency: 1
# Token: blatant, Document Frequency: 1
# Token: blew, Document Frequency: 2
# Token: bloddy, Document Frequency: 1
# Token: blood, Document Frequency: 2
# Token: bloodiest, Document Frequency: 1
# Token: bloody, Document Frequency: 1
# Token: blown, Document Frequency: 2
# Token: blows, Document Frequency: 1
# Token: blue, Document Frequency: 6
# Token: blueant, Document Frequency: 1
# Token: bluetoooth, Document Frequency: 1
# Token: bluetooth, Document Frequency: 13
# Token: bluetooths, Document Frequency: 1
# Token: blush, Document Frequency: 1
# Token: bmw, Document Frequency: 1
# Token: boasts, Document Frequency: 1
# Token: bob, Document Frequency: 1
# Token: boba, Document Frequency: 1
# Token: bodes, Document Frequency: 1
# Token: boiled, Document Frequency: 1
# Token: bold, Document Frequency: 1
# Token: bond, Document Frequency: 1
# Token: bonding, Document Frequency: 1
# Token: bone, Document Frequency: 1
# Token: bonus, Document Frequency: 1
# Token: boobs, Document Frequency: 1
# Token: book, Document Frequency: 4
# Token: booking, Document Frequency: 1
# Token: boost, Document Frequency: 2
# Token: boot, Document Frequency: 3
# Token: bop, Document Frequency: 1
# Token: bordered, Document Frequency: 1
# Token: bore, Document Frequency: 2
# Token: bored, Document Frequency: 3
# Token: boring, Document Frequency: 6
# Token: bose, Document Frequency: 1
# Token: boss, Document Frequency: 1
# Token: both, Document Frequency: 22
# Token: bother, Document Frequency: 5
# Token: bothersome, Document Frequency: 1
# Token: bottom, Document Frequency: 3
# Token: bottowm, Document Frequency: 1
# Token: bouchon, Document Frequency: 1
# Token: bought, Document Frequency: 12
# Token: bougth, Document Frequency: 1
# Token: bowl, Document Frequency: 2
# Token: box, Document Frequency: 2
# Token: boxes, Document Frequency: 1
# Token: boy, Document Frequency: 3
# Token: boyfriend, Document Frequency: 1
# Token: boyle, Document Frequency: 1
# Token: brain, Document Frequency: 2
# Token: brand, Document Frequency: 2
# Token: bread, Document Frequency: 4
# Token: break, Document Frequency: 4
# Token: breakage, Document Frequency: 1
# Token: breakfast, Document Frequency: 9
# Token: breaking, Document Frequency: 3
# Token: breaks, Document Frequency: 3
# Token: breeders, Document Frequency: 1
# Token: breeze, Document Frequency: 1
# Token: brevity, Document Frequency: 1
# Token: brian, Document Frequency: 2
# Token: brick, Document Frequency: 2
# Token: brief, Document Frequency: 2
# Token: brigand, Document Frequency: 1
# Token: bright, Document Frequency: 1
# Token: brilliance, Document Frequency: 2
# Token: brilliant, Document Frequency: 7
# Token: brilliantly, Document Frequency: 1
# Token: bring, Document Frequency: 5
# Token: brings, Document Frequency: 2
# Token: brisket, Document Frequency: 1
# Token: broad, Document Frequency: 1
# Token: broke, Document Frequency: 5
# Token: broken, Document Frequency: 1
# Token: brooding, Document Frequency: 1
# Token: brother, Document Frequency: 2
# Token: brought, Document Frequency: 2
# Token: brownish, Document Frequency: 1
# Token: browser, Document Frequency: 1
# Token: browsing, Document Frequency: 1
# Token: brunch, Document Frequency: 3
# Token: bruschetta, Document Frequency: 1
# Token: brushfire, Document Frequency: 1
# Token: bt, Document Frequency: 4
# Token: btv, Document Frequency: 1
# Token: bucks, Document Frequency: 3
# Token: buddy, Document Frequency: 1
# Token: budget, Document Frequency: 6
# Token: buds, Document Frequency: 1
# Token: buffet, Document Frequency: 10
# Token: buffets, Document Frequency: 1
# Token: build, Document Frequency: 2
# Token: builders, Document Frequency: 1
# Token: building, Document Frequency: 2
# Token: buildings, Document Frequency: 1
# Token: built, Document Frequency: 2
# Token: bulky, Document Frequency: 1
# Token: bullock, Document Frequency: 2
# Token: bully, Document Frequency: 1
# Token: bumpers, Document Frequency: 1
# Token: bunch, Document Frequency: 4
# Token: burger, Document Frequency: 10
# Token: burgers, Document Frequency: 3
# Token: burrittos, Document Frequency: 1
# Token: burton, Document Frequency: 1
# Token: bus, Document Frequency: 1
# Token: business, Document Frequency: 5
# Token: businesses, Document Frequency: 1
# Token: busy, Document Frequency: 3
# Token: but, Document Frequency: 160
# Token: butter, Document Frequency: 2
# Token: button, Document Frequency: 2
# Token: buttons, Document Frequency: 7
# Token: buy, Document Frequency: 15
# Token: buyer, Document Frequency: 2
# Token: buyers, Document Frequency: 1
# Token: buying, Document Frequency: 5
# Token: buyit, Document Frequency: 1
# Token: buzzing, Document Frequency: 1
# Token: by, Document Frequency: 62
# Token: bye, Document Frequency: 2
# Token: ca, Document Frequency: 1
# Token: caballero, Document Frequency: 1
# Token: cable, Document Frequency: 7
# Token: cables, Document Frequency: 1
# Token: caesar, Document Frequency: 1
# Token: cafe, Document Frequency: 3
# Token: cailles, Document Frequency: 1
# Token: cake, Document Frequency: 1
# Token: cakes, Document Frequency: 1
# Token: calamari, Document Frequency: 1
# Token: calendar, Document Frequency: 1
# Token: california, Document Frequency: 1
# Token: call, Document Frequency: 12
# Token: called, Document Frequency: 2
# Token: calligraphy, Document Frequency: 1
# Token: callings, Document Frequency: 1
# Token: calls, Document Frequency: 12
# Token: came, Document Frequency: 27
# Token: cameo, Document Frequency: 1
# Token: camera, Document Frequency: 17
# Token: camerawork, Document Frequency: 1
# Token: can, Document Frequency: 70
# Token: canada, Document Frequency: 1
# Token: cancan, Document Frequency: 1
# Token: cancellation, Document Frequency: 1
# Token: cancelling, Document Frequency: 1
# Token: candace, Document Frequency: 1
# Token: candle, Document Frequency: 1
# Token: cannoli, Document Frequency: 1
# Token: cannot, Document Frequency: 8
# Token: cant, Document Frequency: 4
# Token: capability, Document Frequency: 1
# Token: cape, Document Frequency: 1
# Token: captain, Document Frequency: 1
# Token: car, Document Frequency: 15
# Token: carbs, Document Frequency: 1
# Token: card, Document Frequency: 2
# Token: cardboard, Document Frequency: 2
# Token: cardellini, Document Frequency: 1
# Token: care, Document Frequency: 9
# Token: careful, Document Frequency: 2
# Token: carly, Document Frequency: 1
# Token: carol, Document Frequency: 1
# Token: carpaccio, Document Frequency: 1
# Token: carrell, Document Frequency: 1
# Token: carried, Document Frequency: 1
# Token: carriers, Document Frequency: 1
# Token: carries, Document Frequency: 1
# Token: carry, Document Frequency: 2
# Token: cars, Document Frequency: 1
# Token: cart, Document Frequency: 1
# Token: cartoon, Document Frequency: 1
# Token: cartoons, Document Frequency: 2
# Token: case, Document Frequency: 30
# Token: cases, Document Frequency: 5
# Token: cash, Document Frequency: 1
# Token: cashew, Document Frequency: 1
# Token: cashier, Document Frequency: 2
# Token: casing, Document Frequency: 1
# Token: casino, Document Frequency: 1
# Token: cast, Document Frequency: 15
# Token: casted, Document Frequency: 1
# Token: casting, Document Frequency: 5
# Token: cat, Document Frequency: 1
# Token: catching, Document Frequency: 2
# Token: catchy, Document Frequency: 1
# Token: caterpillar, Document Frequency: 1
# Token: caught, Document Frequency: 1
# Token: cause, Document Frequency: 3
# Token: caused, Document Frequency: 1
# Token: causing, Document Frequency: 1
# Token: cavier, Document Frequency: 1
# Token: cbr, Document Frequency: 1
# Token: cds, Document Frequency: 1
# Token: ceases, Document Frequency: 1
# Token: celebration, Document Frequency: 1
# Token: celebrity, Document Frequency: 1
# Token: cell, Document Frequency: 11
# Token: cellphone, Document Frequency: 2
# Token: cellphones, Document Frequency: 1
# Token: cellular, Document Frequency: 1
# Token: cent, Document Frequency: 1
# Token: center, Document Frequency: 1
# Token: centers, Document Frequency: 1
# Token: central, Document Frequency: 2
# Token: century, Document Frequency: 2
# Token: certain, Document Frequency: 2
# Token: certainly, Document Frequency: 9
# Token: cg, Document Frequency: 1
# Token: cgi, Document Frequency: 1
# Token: chains, Document Frequency: 1
# Token: chalkboard, Document Frequency: 1
# Token: challenges, Document Frequency: 1
# Token: chance, Document Frequency: 2
# Token: change, Document Frequency: 2
# Token: changes, Document Frequency: 1
# Token: changing, Document Frequency: 3
# Token: channel, Document Frequency: 1
# Token: char, Document Frequency: 2
# Token: character, Document Frequency: 17
# Token: characterisation, Document Frequency: 1
# Token: characters, Document Frequency: 31
# Token: charcoal, Document Frequency: 2
# Token: charge, Document Frequency: 13
# Token: charged, Document Frequency: 4
# Token: charger, Document Frequency: 14
# Token: chargers, Document Frequency: 2
# Token: charges, Document Frequency: 1
# Token: charging, Document Frequency: 5
# Token: charisma, Document Frequency: 2
# Token: charismatic, Document Frequency: 1
# Token: charles, Document Frequency: 1
# Token: charlie, Document Frequency: 1
# Token: charm, Document Frequency: 6
# Token: charming, Document Frequency: 3
# Token: chase, Document Frequency: 1
# Token: chasing, Document Frequency: 1
# Token: cheap, Document Frequency: 13
# Token: cheaper, Document Frequency: 1
# Token: cheaply, Document Frequency: 2
# Token: check, Document Frequency: 7
# Token: checked, Document Frequency: 4
# Token: checking, Document Frequency: 3
# Token: cheek, Document Frequency: 2
# Token: cheekbones, Document Frequency: 1
# Token: cheerfull, Document Frequency: 1
# Token: cheerless, Document Frequency: 1
# Token: cheese, Document Frequency: 2
# Token: cheeseburger, Document Frequency: 1
# Token: cheesecurds, Document Frequency: 1
# Token: cheesiness, Document Frequency: 1
# Token: cheesy, Document Frequency: 2
# Token: chef, Document Frequency: 4
# Token: chemistry, Document Frequency: 4
# Token: chewy, Document Frequency: 3
# Token: chick, Document Frequency: 2
# Token: chicken, Document Frequency: 14
# Token: child, Document Frequency: 6
# Token: childhood, Document Frequency: 1
# Token: children, Document Frequency: 3
# Token: chilly, Document Frequency: 2
# Token: chimp, Document Frequency: 1
# Token: china, Document Frequency: 1
# Token: chinese, Document Frequency: 3
# Token: chip, Document Frequency: 1
# Token: chipolte, Document Frequency: 1
# Token: chipotle, Document Frequency: 1
# Token: chips, Document Frequency: 5
# Token: chodorov, Document Frequency: 1
# Token: choice, Document Frequency: 3
# Token: choices, Document Frequency: 1
# Token: choose, Document Frequency: 1
# Token: chosen, Document Frequency: 1
# Token: choux, Document Frequency: 1
# Token: chow, Document Frequency: 2
# Token: christmas, Document Frequency: 2
# Token: christopher, Document Frequency: 1
# Token: church, Document Frequency: 2
# Token: cinema, Document Frequency: 7
# Token: cinematography, Document Frequency: 7
# Token: cingulair, Document Frequency: 1
# Token: cingular, Document Frequency: 4
# Token: circumstances, Document Frequency: 2
# Token: claimed, Document Frequency: 1
# Token: clarity, Document Frequency: 3
# Token: class, Document Frequency: 1
# Token: classic, Document Frequency: 3
# Token: classical, Document Frequency: 1
# Token: classics, Document Frequency: 1
# Token: classy, Document Frequency: 1
# Token: clean, Document Frequency: 8
# Token: clear, Document Frequency: 11
# Token: clearer, Document Frequency: 1
# Token: clearly, Document Frequency: 4
# Token: clever, Document Frequency: 5
# Token: cliche, Document Frequency: 1
# Token: clichés, Document Frequency: 3
# Token: clicks, Document Frequency: 1
# Token: clients, Document Frequency: 1
# Token: climax, Document Frequency: 1
# Token: clip, Document Frequency: 4
# Token: clipping, Document Frequency: 1
# Token: clips, Document Frequency: 1
# Token: clock, Document Frequency: 1
# Token: close, Document Frequency: 7
# Token: closed, Document Frequency: 1
# Token: clothes, Document Frequency: 1
# Token: club, Document Frequency: 1
# Token: co, Document Frequency: 1
# Token: coach, Document Frequency: 1
# Token: coal, Document Frequency: 1
# Token: coaster, Document Frequency: 1
# Token: cocktail, Document Frequency: 1
# Token: cocktails, Document Frequency: 1
# Token: coconut, Document Frequency: 1
# Token: cod, Document Frequency: 1
# Token: coffee, Document Frequency: 1
# Token: coherent, Document Frequency: 1
# Token: cold, Document Frequency: 7
# Token: colder, Document Frequency: 1
# Token: cole, Document Frequency: 2
# Token: colleague, Document Frequency: 1
# Token: collect, Document Frequency: 1
# Token: color, Document Frequency: 7
# Token: colored, Document Frequency: 2
# Token: colorful, Document Frequency: 1
# Token: colors, Document Frequency: 1
# Token: columbo, Document Frequency: 1
# Token: combination, Document Frequency: 2
# Token: combo, Document Frequency: 1
# Token: come, Document Frequency: 13
# Token: comedic, Document Frequency: 1
# Token: comedy, Document Frequency: 2
# Token: comes, Document Frequency: 7
# Token: comfort, Document Frequency: 3
# Token: comfortable, Document Frequency: 14
# Token: comfortably, Document Frequency: 3
# Token: comfortible, Document Frequency: 1
# Token: comforting, Document Frequency: 1
# Token: comical, Document Frequency: 1
# Token: coming, Document Frequency: 12
# Token: commands, Document Frequency: 1
# Token: commentary, Document Frequency: 1
# Token: commented, Document Frequency: 1
# Token: comments, Document Frequency: 2
# Token: commercial, Document Frequency: 1
# Token: commercials, Document Frequency: 1
# Token: common, Document Frequency: 1
# Token: communicate, Document Frequency: 1
# Token: communications, Document Frequency: 1
# Token: community, Document Frequency: 1
# Token: commuter, Document Frequency: 1
# Token: companions, Document Frequency: 1
# Token: company, Document Frequency: 6
# Token: compared, Document Frequency: 1
# Token: compelling, Document Frequency: 1
# Token: compete, Document Frequency: 1
# Token: competent, Document Frequency: 1
# Token: complain, Document Frequency: 2
# Token: complaint, Document Frequency: 2
# Token: complaints, Document Frequency: 3
# Token: complete, Document Frequency: 4
# Token: completed, Document Frequency: 1
# Token: completely, Document Frequency: 9
# Token: complex, Document Frequency: 2
# Token: complexity, Document Frequency: 1
# Token: compliments, Document Frequency: 2
# Token: composed, Document Frequency: 1
# Token: composition, Document Frequency: 2
# Token: comprehensible, Document Frequency: 1
# Token: compromise, Document Frequency: 1
# Token: computer, Document Frequency: 5
# Token: con, Document Frequency: 1
# Token: concentrate, Document Frequency: 1
# Token: concept, Document Frequency: 1
# Token: conception, Document Frequency: 1
# Token: conceptually, Document Frequency: 1
# Token: concern, Document Frequency: 1
# Token: concert, Document Frequency: 1
# Token: conclusion, Document Frequency: 4
# Token: concrete, Document Frequency: 1
# Token: condescends, Document Frequency: 1
# Token: condiment, Document Frequency: 1
# Token: conditions, Document Frequency: 1
# Token: confidence, Document Frequency: 1
# Token: configuration, Document Frequency: 1
# Token: confirm, Document Frequency: 1
# Token: conflict, Document Frequency: 2
# Token: confuses, Document Frequency: 1
# Token: connect, Document Frequency: 1
# Token: connected, Document Frequency: 2
# Token: connecting, Document Frequency: 1
# Token: connection, Document Frequency: 4
# Token: connections, Document Frequency: 1
# Token: connery, Document Frequency: 2
# Token: connisseur, Document Frequency: 1
# Token: connoisseur, Document Frequency: 1
# Token: connor, Document Frequency: 1
# Token: consequences, Document Frequency: 1
# Token: consider, Document Frequency: 4
# Token: considerable, Document Frequency: 1
# Token: considered, Document Frequency: 1
# Token: considering, Document Frequency: 6
# Token: considers, Document Frequency: 1
# Token: consistent, Document Frequency: 1
# Token: consolations, Document Frequency: 1
# Token: constantine, Document Frequency: 1
# Token: constantly, Document Frequency: 1
# Token: constructed, Document Frequency: 3
# Token: construction, Document Frequency: 3
# Token: consumer, Document Frequency: 1
# Token: contact, Document Frequency: 1
# Token: contacted, Document Frequency: 1
# Token: contacting, Document Frequency: 1
# Token: contacts, Document Frequency: 2
# Token: contained, Document Frequency: 2
# Token: containers, Document Frequency: 1
# Token: contains, Document Frequency: 2
# Token: content, Document Frequency: 1
# Token: continuation, Document Frequency: 1
# Token: continue, Document Frequency: 3
# Token: continuity, Document Frequency: 2
# Token: continuously, Document Frequency: 1
# Token: contract, Document Frequency: 2
# Token: contrast, Document Frequency: 2
# Token: contributing, Document Frequency: 1
# Token: contributory, Document Frequency: 1
# Token: control, Document Frequency: 3
# Token: controls, Document Frequency: 1
# Token: controversy, Document Frequency: 1
# Token: contstruct, Document Frequency: 1
# Token: convenient, Document Frequency: 3
# Token: convention, Document Frequency: 1
# Token: conversation, Document Frequency: 1
# Token: conversations, Document Frequency: 2
# Token: converter, Document Frequency: 1
# Token: convey, Document Frequency: 1
# Token: convince, Document Frequency: 1
# Token: convincing, Document Frequency: 2
# Token: convoluted, Document Frequency: 1
# Token: cook, Document Frequency: 2
# Token: cooked, Document Frequency: 6
# Token: cool, Document Frequency: 17
# Token: coppola, Document Frequency: 2
# Token: copy, Document Frequency: 1
# Token: cords, Document Frequency: 1
# Token: core, Document Frequency: 2
# Token: corn, Document Frequency: 2
# Token: corny, Document Frequency: 1
# Token: correct, Document Frequency: 2
# Token: correction, Document Frequency: 1
# Token: correctly, Document Frequency: 1
# Token: cost, Document Frequency: 3
# Token: costco, Document Frequency: 1
# Token: costs, Document Frequency: 4
# Token: costumes, Document Frequency: 2
# Token: cotta, Document Frequency: 1
# Token: could, Document Frequency: 42
# Token: couldn, Document Frequency: 13
# Token: couldnt, Document Frequency: 1
# Token: count, Document Frequency: 1
# Token: counterfeit, Document Frequency: 1
# Token: couple, Document Frequency: 8
# Token: couples, Document Frequency: 1
# Token: coupons, Document Frequency: 1
# Token: course, Document Frequency: 3
# Token: court, Document Frequency: 2
# Token: courteous, Document Frequency: 1
# Token: courtroom, Document Frequency: 2
# Token: cover, Document Frequency: 3
# Token: coverage, Document Frequency: 2
# Token: covered, Document Frequency: 2
# Token: covers, Document Frequency: 1
# Token: cow, Document Frequency: 2
# Token: cox, Document Frequency: 1
# Token: coziness, Document Frequency: 1
# Token: crab, Document Frequency: 2
# Token: crack, Document Frequency: 1
# Token: crackles, Document Frequency: 1
# Token: cradle, Document Frequency: 1
# Token: cradles, Document Frequency: 1
# Token: crafted, Document Frequency: 1
# Token: cramming, Document Frequency: 1
# Token: cranberry, Document Frequency: 1
# Token: crap, Document Frequency: 9
# Token: crash, Document Frequency: 1
# Token: crashed, Document Frequency: 1
# Token: craving, Document Frequency: 1
# Token: crawfish, Document Frequency: 1
# Token: crawl, Document Frequency: 1
# Token: crayon, Document Frequency: 1
# Token: crazy, Document Frequency: 3
# Token: creaks, Document Frequency: 1
# Token: cream, Document Frequency: 3
# Token: creamy, Document Frequency: 2
# Token: create, Document Frequency: 2
# Token: created, Document Frequency: 4
# Token: creates, Document Frequency: 2
# Token: creative, Document Frequency: 1
# Token: creativity, Document Frequency: 1
# Token: creature, Document Frequency: 1
# Token: credible, Document Frequency: 1
# Token: credit, Document Frequency: 3
# Token: credits, Document Frequency: 1
# Token: crepe, Document Frequency: 1
# Token: crew, Document Frequency: 1
# Token: crime, Document Frequency: 1
# Token: crisp, Document Frequency: 4
# Token: crispy, Document Frequency: 2
# Token: critic, Document Frequency: 1
# Token: critical, Document Frequency: 1
# Token: cross, Document Frequency: 1
# Token: crostini, Document Frequency: 1
# Token: croutons, Document Frequency: 1
# Token: crowd, Document Frequency: 4
# Token: crowds, Document Frequency: 1
# Token: cruel, Document Frequency: 1
# Token: cruise, Document Frequency: 1
# Token: crumby, Document Frequency: 1
# Token: crust, Document Frequency: 1
# Token: crusty, Document Frequency: 1
# Token: cry, Document Frequency: 1
# Token: crystals, Document Frequency: 1
# Token: cuisine, Document Frequency: 1
# Token: cult, Document Frequency: 3
# Token: culture, Document Frequency: 2
# Token: cumbersome, Document Frequency: 2
# Token: current, Document Frequency: 2
# Token: currently, Document Frequency: 1
# Token: curry, Document Frequency: 2
# Token: curve, Document Frequency: 1
# Token: custer, Document Frequency: 1
# Token: customer, Document Frequency: 13
# Token: customers, Document Frequency: 2
# Token: customize, Document Frequency: 1
# Token: cut, Document Frequency: 3
# Token: cute, Document Frequency: 5
# Token: cutest, Document Frequency: 1
# Token: cutouts, Document Frequency: 2
# Token: cuts, Document Frequency: 1
# Token: cutting, Document Frequency: 1
# Token: dads, Document Frequency: 1
# Token: damian, Document Frequency: 1
# Token: damn, Document Frequency: 5
# Token: dance, Document Frequency: 3
# Token: dancing, Document Frequency: 2
# Token: dangerous, Document Frequency: 1
# Token: dark, Document Frequency: 3
# Token: darren, Document Frequency: 1
# Token: data, Document Frequency: 3
# Token: date, Document Frequency: 3
# Token: dates, Document Frequency: 1
# Token: daughter, Document Frequency: 2
# Token: daughters, Document Frequency: 1
# Token: day, Document Frequency: 16
# Token: days, Document Frequency: 7
# Token: de, Document Frequency: 2
# Token: dead, Document Frequency: 6
# Token: deadly, Document Frequency: 1
# Token: deadpan, Document Frequency: 1
# Token: deaf, Document Frequency: 1
# Token: deal, Document Frequency: 10
# Token: dealt, Document Frequency: 1
# Token: death, Document Frequency: 3
# Token: debated, Document Frequency: 1
# Token: debbie, Document Frequency: 1
# Token: debits, Document Frequency: 1
# Token: debut, Document Frequency: 1
# Token: decade, Document Frequency: 1
# Token: decay, Document Frequency: 2
# Token: decent, Document Frequency: 6
# Token: decided, Document Frequency: 2
# Token: decision, Document Frequency: 3
# Token: decisions, Document Frequency: 1
# Token: decor, Document Frequency: 2
# Token: decorated, Document Frequency: 2
# Token: dee, Document Frequency: 1
# Token: deep, Document Frequency: 2
# Token: deeply, Document Frequency: 2
# Token: def, Document Frequency: 1
# Token: defect, Document Frequency: 1
# Token: defective, Document Frequency: 2
# Token: deffinitely, Document Frequency: 1
# Token: definately, Document Frequency: 1
# Token: defined, Document Frequency: 1
# Token: definitely, Document Frequency: 27
# Token: definitly, Document Frequency: 1
# Token: del, Document Frequency: 1
# Token: delay, Document Frequency: 1
# Token: delete, Document Frequency: 1
# Token: delicious, Document Frequency: 18
# Token: deliciously, Document Frequency: 1
# Token: delight, Document Frequency: 1
# Token: delightful, Document Frequency: 2
# Token: delights, Document Frequency: 2
# Token: delish, Document Frequency: 3
# Token: deliver, Document Frequency: 1
# Token: delivered, Document Frequency: 1
# Token: delivering, Document Frequency: 1
# Token: delivers, Document Frequency: 3
# Token: delivery, Document Frequency: 1
# Token: denny, Document Frequency: 1
# Token: dependant, Document Frequency: 1
# Token: depicted, Document Frequency: 1
# Token: depicts, Document Frequency: 1
# Token: depressing, Document Frequency: 2
# Token: depth, Document Frequency: 4
# Token: derivative, Document Frequency: 1
# Token: describe, Document Frequency: 3
# Token: described, Document Frequency: 2
# Token: describes, Document Frequency: 1
# Token: describing, Document Frequency: 1
# Token: description, Document Frequency: 2
# Token: descriptions, Document Frequency: 1
# Token: desert, Document Frequency: 1
# Token: deserved, Document Frequency: 2
# Token: deserves, Document Frequency: 4
# Token: deserving, Document Frequency: 2
# Token: design, Document Frequency: 9
# Token: designed, Document Frequency: 2
# Token: designer, Document Frequency: 1
# Token: designs, Document Frequency: 1
# Token: desired, Document Frequency: 1
# Token: desperation, Document Frequency: 1
# Token: despicable, Document Frequency: 1
# Token: despised, Document Frequency: 1
# Token: despite, Document Frequency: 4
# Token: dessert, Document Frequency: 5
# Token: desserts, Document Frequency: 2
# Token: destination, Document Frequency: 1
# Token: destroy, Document Frequency: 1
# Token: destroying, Document Frequency: 1
# Token: detachable, Document Frequency: 1
# Token: detailed, Document Frequency: 1
# Token: detailing, Document Frequency: 1
# Token: details, Document Frequency: 1
# Token: deuchebaggery, Document Frequency: 1
# Token: develop, Document Frequency: 1
# Token: development, Document Frequency: 2
# Token: developments, Document Frequency: 1
# Token: device, Document Frequency: 7
# Token: devices, Document Frequency: 1
# Token: devine, Document Frequency: 1
# Token: di, Document Frequency: 1
# Token: diabetic, Document Frequency: 1
# Token: dialing, Document Frequency: 2
# Token: dialog, Document Frequency: 3
# Token: dialogs, Document Frequency: 1
# Token: dialogue, Document Frequency: 12
# Token: diaper, Document Frequency: 1
# Token: dickens, Document Frequency: 1
# Token: did, Document Frequency: 40
# Token: didn, Document Frequency: 37
# Token: die, Document Frequency: 2
# Token: died, Document Frequency: 1
# Token: dieing, Document Frequency: 1
# Token: difference, Document Frequency: 2
# Token: different, Document Frequency: 11
# Token: difficult, Document Frequency: 6
# Token: dimensional, Document Frequency: 1
# Token: dine, Document Frequency: 2
# Token: dining, Document Frequency: 4
# Token: dinner, Document Frequency: 4
# Token: dinners, Document Frequency: 1
# Token: dipping, Document Frequency: 1
# Token: direct, Document Frequency: 1
# Token: directed, Document Frequency: 3
# Token: directing, Document Frequency: 6
# Token: direction, Document Frequency: 5
# Token: directions, Document Frequency: 1
# Token: director, Document Frequency: 11
# Token: directorial, Document Frequency: 2
# Token: directors, Document Frequency: 2
# Token: dirt, Document Frequency: 2
# Token: dirty, Document Frequency: 4
# Token: disagree, Document Frequency: 1
# Token: disapoinment, Document Frequency: 1
# Token: disapointing, Document Frequency: 1
# Token: disappoint, Document Frequency: 2
# Token: disappointed, Document Frequency: 32
# Token: disappointing, Document Frequency: 11
# Token: disappointment, Document Frequency: 9
# Token: disapppointment, Document Frequency: 1
# Token: disaster, Document Frequency: 3
# Token: discarded, Document Frequency: 1
# Token: discomfort, Document Frequency: 2
# Token: disconnected, Document Frequency: 1
# Token: discount, Document Frequency: 2
# Token: discovering, Document Frequency: 2
# Token: discovery, Document Frequency: 1
# Token: disgrace, Document Frequency: 2
# Token: disgraceful, Document Frequency: 1
# Token: disgust, Document Frequency: 1
# Token: disgusted, Document Frequency: 1
# Token: disgusting, Document Frequency: 4
# Token: dish, Document Frequency: 6
# Token: dishes, Document Frequency: 7
# Token: dislike, Document Frequency: 2
# Token: disliked, Document Frequency: 2
# Token: disney, Document Frequency: 1
# Token: disparate, Document Frequency: 1
# Token: dispenser, Document Frequency: 1
# Token: display, Document Frequency: 2
# Token: displeased, Document Frequency: 1
# Token: disrespected, Document Frequency: 1
# Token: dissapointed, Document Frequency: 1
# Token: dissapointing, Document Frequency: 1
# Token: distinction, Document Frequency: 1
# Token: distorted, Document Frequency: 2
# Token: distract, Document Frequency: 1
# Token: distracting, Document Frequency: 1
# Token: distressed, Document Frequency: 1
# Token: disturbing, Document Frequency: 2
# Token: dit, Document Frequency: 1
# Token: division, Document Frequency: 1
# Token: dna, Document Frequency: 1
# Token: do, Document Frequency: 41
# Token: docking, Document Frequency: 1
# Token: doctor, Document Frequency: 2
# Token: documentaries, Document Frequency: 2
# Token: documentary, Document Frequency: 3
# Token: dodge, Document Frequency: 1
# Token: does, Document Frequency: 28
# Token: doesn, Document Frequency: 24
# Token: dog, Document Frequency: 1
# Token: dogs, Document Frequency: 1
# Token: doing, Document Frequency: 4
# Token: dollar, Document Frequency: 1
# Token: dollars, Document Frequency: 2
# Token: dominated, Document Frequency: 1
# Token: don, Document Frequency: 63
# Token: done, Document Frequency: 12
# Token: donlevy, Document Frequency: 1
# Token: dont, Document Frequency: 3
# Token: doomed, Document Frequency: 1
# Token: door, Document Frequency: 3
# Token: dosen, Document Frequency: 1
# Token: double, Document Frequency: 2
# Token: doubt, Document Frequency: 3
# Token: douchey, Document Frequency: 1
# Token: dough, Document Frequency: 1
# Token: doughy, Document Frequency: 1
# Token: down, Document Frequency: 18
# Token: download, Document Frequency: 1
# Token: downs, Document Frequency: 1
# Token: downtown, Document Frequency: 2
# Token: dozen, Document Frequency: 2
# Token: dozens, Document Frequency: 1
# Token: dr, Document Frequency: 1
# Token: dracula, Document Frequency: 1
# Token: draft, Document Frequency: 1
# Token: drag, Document Frequency: 2
# Token: drago, Document Frequency: 4
# Token: drain, Document Frequency: 3
# Token: drained, Document Frequency: 1
# Token: drains, Document Frequency: 1
# Token: drama, Document Frequency: 6
# Token: dramatic, Document Frequency: 2
# Token: drawing, Document Frequency: 1
# Token: drawings, Document Frequency: 1
# Token: drawn, Document Frequency: 1
# Token: dream, Document Frequency: 1
# Token: dreamed, Document Frequency: 1
# Token: dreams, Document Frequency: 1
# Token: dreary, Document Frequency: 1
# Token: drenched, Document Frequency: 1
# Token: dressed, Document Frequency: 1
# Token: dressing, Document Frequency: 2
# Token: dribble, Document Frequency: 1
# Token: dried, Document Frequency: 1
# Token: driest, Document Frequency: 2
# Token: drift, Document Frequency: 1
# Token: drifting, Document Frequency: 1
# Token: drink, Document Frequency: 3
# Token: drinking, Document Frequency: 1
# Token: drinks, Document Frequency: 4
# Token: dripping, Document Frequency: 1
# Token: drive, Document Frequency: 6
# Token: driving, Document Frequency: 3
# Token: drooling, Document Frequency: 1
# Token: drop, Document Frequency: 2
# Token: dropped, Document Frequency: 8
# Token: dropping, Document Frequency: 2
# Token: drops, Document Frequency: 2
# Token: dry, Document Frequency: 4
# Token: dual, Document Frequency: 1
# Token: duck, Document Frequency: 2
# Token: dude, Document Frequency: 1
# Token: due, Document Frequency: 4
# Token: duet, Document Frequency: 2
# Token: dull, Document Frequency: 2
# Token: dumb, Document Frequency: 1
# Token: dumbest, Document Frequency: 1
# Token: duo, Document Frequency: 1
# Token: duper, Document Frequency: 1
# Token: durable, Document Frequency: 1
# Token: during, Document Frequency: 9
# Token: duris, Document Frequency: 1
# Token: dusted, Document Frequency: 1
# Token: dvd, Document Frequency: 1
# Token: dwight, Document Frequency: 1
# Token: dying, Document Frequency: 2
# Token: dylan, Document Frequency: 1
# Token: dysfunction, Document Frequency: 1
# Token: each, Document Frequency: 13
# Token: ear, Document Frequency: 29
# Token: earbud, Document Frequency: 3
# Token: earbuds, Document Frequency: 1
# Token: earbugs, Document Frequency: 1
# Token: eargels, Document Frequency: 1
# Token: earlier, Document Frequency: 3
# Token: early, Document Frequency: 3
# Token: earpad, Document Frequency: 1
# Token: earphone, Document Frequency: 1
# Token: earpiece, Document Frequency: 3
# Token: earpieces, Document Frequency: 2
# Token: ears, Document Frequency: 6
# Token: earset, Document Frequency: 1
# Token: earth, Document Frequency: 2
# Token: ease, Document Frequency: 3
# Token: easier, Document Frequency: 3
# Token: easily, Document Frequency: 9
# Token: easy, Document Frequency: 18
# Token: eat, Document Frequency: 16
# Token: eaten, Document Frequency: 5
# Token: eating, Document Frequency: 7
# Token: ebay, Document Frequency: 1
# Token: ebola, Document Frequency: 1
# Token: eccleston, Document Frequency: 1
# Token: echo, Document Frequency: 2
# Token: eclectic, Document Frequency: 1
# Token: ed, Document Frequency: 2
# Token: edge, Document Frequency: 3
# Token: edible, Document Frequency: 2
# Token: edinburgh, Document Frequency: 1
# Token: editing, Document Frequency: 4
# Token: educational, Document Frequency: 1
# Token: edward, Document Frequency: 1
# Token: eel, Document Frequency: 1
# Token: eew, Document Frequency: 1
# Token: effect, Document Frequency: 2
# Token: effective, Document Frequency: 3
# Token: effects, Document Frequency: 9
# Token: efficient, Document Frequency: 1
# Token: effort, Document Frequency: 3
# Token: egg, Document Frequency: 3
# Token: eggplant, Document Frequency: 2
# Token: eggs, Document Frequency: 1
# Token: eiko, Document Frequency: 1
# Token: either, Document Frequency: 11
# Token: elaborately, Document Frequency: 1
# Token: elderly, Document Frequency: 1
# Token: electronics, Document Frequency: 1
# Token: elegant, Document Frequency: 2
# Token: elegantly, Document Frequency: 1
# Token: element, Document Frequency: 1
# Token: elias, Document Frequency: 1
# Token: elk, Document Frequency: 1
# Token: eloquently, Document Frequency: 1
# Token: else, Document Frequency: 8
# Token: elsewhere, Document Frequency: 6
# Token: email, Document Frequency: 1
# Token: embarassing, Document Frequency: 1
# Token: embarrassing, Document Frequency: 3
# Token: embassy, Document Frequency: 1
# Token: embedded, Document Frequency: 1
# Token: emilio, Document Frequency: 2
# Token: emily, Document Frequency: 2
# Token: emoting, Document Frequency: 1
# Token: emotion, Document Frequency: 1
# Token: emotionally, Document Frequency: 1
# Token: emperor, Document Frequency: 1
# ...
# Token: treasure, Document Frequency: 1
# Token: treat, Document Frequency: 3
# Token: treated, Document Frequency: 3
# Token: trek, Document Frequency: 1
# Token: tremendous, Document Frequency: 3
# Token: tremendously, Document Frequency: 1
# Token: treo, Document Frequency: 3
# Token: tribute, Document Frequency: 2
# Token: tricky, Document Frequency: 1
# Token: tried, Document Frequency: 10
# Token: trilogy, Document Frequency: 2
# Token: trimmed, Document Frequency: 1
# Token: trip, Document Frequency: 2
# Token: trippy, Document Frequency: 1
# Token: trips, Document Frequency: 1
# Token: triumphed, Document Frequency: 1
# Token: trond, Document Frequency: 1
# Token: trooper, Document Frequency: 1
# Token: trouble, Document Frequency: 3
# Token: true, Document Frequency: 3
# Token: truffle, Document Frequency: 1
# Token: truly, Document Frequency: 9
# Token: trumbull, Document Frequency: 1
# Token: trumpeter, Document Frequency: 1
# Token: trunk, Document Frequency: 1
# Token: trust, Document Frequency: 1
# Token: truth, Document Frequency: 1
# Token: try, Document Frequency: 14
# Token: trying, Document Frequency: 8
# Token: trysts, Document Frequency: 1
# Token: tsunami, Document Frequency: 1
# Token: tucson, Document Frequency: 1
# Token: tummy, Document Frequency: 1
# Token: tuna, Document Frequency: 2
# Token: tuneful, Document Frequency: 1
# Token: turkey, Document Frequency: 2
# Token: turn, Document Frequency: 7
# Token: turned, Document Frequency: 3
# Token: turns, Document Frequency: 4
# Token: tv, Document Frequency: 10
# Token: twice, Document Frequency: 7
# Token: twirling, Document Frequency: 1
# Token: twist, Document Frequency: 1
# Token: twists, Document Frequency: 1
# Token: two, Document Frequency: 27
# Token: tying, Document Frequency: 1
# Token: type, Document Frequency: 4
# Token: typical, Document Frequency: 1
# Token: ugliest, Document Frequency: 1
# Token: ugly, Document Frequency: 1
# Token: uhura, Document Frequency: 1
# Token: ultra, Document Frequency: 1
# Token: um, Document Frequency: 1
# Token: unacceptable, Document Frequency: 2
# Token: unacceptible, Document Frequency: 1
# Token: unbearable, Document Frequency: 2
# Token: unbearably, Document Frequency: 1
# Token: unbelievable, Document Frequency: 4
# Token: unbelievably, Document Frequency: 1
# Token: uncalled, Document Frequency: 1
# Token: uncomfortable, Document Frequency: 3
# Token: unconditional, Document Frequency: 1
# Token: unconvincing, Document Frequency: 3
# Token: under, Document Frequency: 8
# Token: underacting, Document Frequency: 1
# Token: underappreciated, Document Frequency: 1
# Token: underbite, Document Frequency: 1
# Token: undercooked, Document Frequency: 1
# Token: underlines, Document Frequency: 1
# Token: underlying, Document Frequency: 2
# Token: underneath, Document Frequency: 1
# Token: underrated, Document Frequency: 1
# Token: understand, Document Frequency: 10
# Token: understanding, Document Frequency: 2
# Token: understated, Document Frequency: 2
# Token: understatement, Document Frequency: 1
# Token: undertone, Document Frequency: 1
# Token: underwater, Document Frequency: 1
# Token: undoubtedly, Document Frequency: 2
# Token: unemployed, Document Frequency: 1
# Token: unethical, Document Frequency: 1
# Token: unfolds, Document Frequency: 2
# Token: unforgettable, Document Frequency: 1
# Token: unfortunately, Document Frequency: 9
# Token: unfunny, Document Frequency: 2
# Token: unhappy, Document Frequency: 2
# Token: uninspired, Document Frequency: 1
# Token: unintelligible, Document Frequency: 1
# Token: unintentionally, Document Frequency: 1
# Token: uninteresting, Document Frequency: 1
# Token: union, Document Frequency: 1
# Token: unique, Document Frequency: 2
# Token: uniqueness, Document Frequency: 1
# Token: unit, Document Frequency: 5
# Token: units, Document Frequency: 1
# Token: universe, Document Frequency: 1
# Token: unknown, Document Frequency: 1
# Token: unless, Document Frequency: 7
# Token: unlike, Document Frequency: 1
# Token: unlockable, Document Frequency: 1
# Token: unmitigated, Document Frequency: 1
# Token: unmoving, Document Frequency: 1
# Token: unnecessary, Document Frequency: 1
# Token: unneeded, Document Frequency: 1
# Token: unoriginal, Document Frequency: 1
# Token: unpleasant, Document Frequency: 1
# Token: unpredictable, Document Frequency: 1
# Token: unprofessional, Document Frequency: 1
# Token: unreal, Document Frequency: 1
# Token: unrealistic, Document Frequency: 1
# Token: unrecognizable, Document Frequency: 2
# Token: unrecommended, Document Frequency: 1
# Token: unreliable, Document Frequency: 4
# Token: unremarkable, Document Frequency: 1
# Token: unrestrained, Document Frequency: 1
# Token: unsatisfactory, Document Frequency: 1
# Token: unsatisfying, Document Frequency: 1
# Token: until, Document Frequency: 5
# Token: untoasted, Document Frequency: 1
# Token: unusable, Document Frequency: 2
# Token: unwatchable, Document Frequency: 1
# Token: unwelcome, Document Frequency: 1
# Token: unwrapped, Document Frequency: 1
# Token: up, Document Frequency: 58
# Token: upa, Document Frequency: 1
# Token: update, Document Frequency: 2
# Token: upgrade, Document Frequency: 1
# Token: uplifting, Document Frequency: 2
# Token: upload, Document Frequency: 1
# Token: uploaded, Document Frequency: 1
# Token: upper, Document Frequency: 1
# Token: ups, Document Frequency: 4
# Token: upstairs, Document Frequency: 1
# Token: uptight, Document Frequency: 1
# Token: ursula, Document Frequency: 1
# Token: us, Document Frequency: 23
# Token: usable, Document Frequency: 1
# Token: usage, Document Frequency: 1
# Token: usb, Document Frequency: 3
# Token: use, Document Frequency: 40
# Token: used, Document Frequency: 18
# Token: useful, Document Frequency: 1
# Token: usefulness, Document Frequency: 1
# Token: useless, Document Frequency: 7
# Token: user, Document Frequency: 2
# Token: uses, Document Frequency: 1
# Token: using, Document Frequency: 11
# Token: ussr, Document Frequency: 1
# Token: usual, Document Frequency: 4
# Token: usually, Document Frequency: 2
# Token: utter, Document Frequency: 2
# Token: utterly, Document Frequency: 4
# Token: vacant, Document Frequency: 1
# Token: vain, Document Frequency: 1
# Token: valentine, Document Frequency: 1
# Token: value, Document Frequency: 5
# Token: values, Document Frequency: 3
# Token: vampire, Document Frequency: 1
# Token: vandiver, Document Frequency: 1
# Token: vanilla, Document Frequency: 1
# Token: variation, Document Frequency: 1
# Token: vc, Document Frequency: 1
# Token: ve, Document Frequency: 46
# Token: veal, Document Frequency: 1
# Token: vegan, Document Frequency: 1
# Token: vegas, Document Frequency: 17
# Token: vegetables, Document Frequency: 3
# Token: veggie, Document Frequency: 1
# Token: veggitarian, Document Frequency: 1
# Token: vehicle, Document Frequency: 1
# Token: vehicles, Document Frequency: 1
# Token: velvet, Document Frequency: 1
# Token: ventura, Document Frequency: 1
# Token: venture, Document Frequency: 1
# Token: venturing, Document Frequency: 1
# Token: venue, Document Frequency: 1
# Token: verbal, Document Frequency: 1
# Token: verbatim, Document Frequency: 1
# Token: verge, Document Frequency: 1
# Token: verizon, Document Frequency: 6
# Token: versatile, Document Frequency: 1
# Token: version, Document Frequency: 1
# Token: very, Document Frequency: 204
# Token: vessel, Document Frequency: 1
# Token: veteran, Document Frequency: 1
# Token: vey, Document Frequency: 1
# Token: vi, Document Frequency: 2
# Token: via, Document Frequency: 1
# Token: vibe, Document Frequency: 4
# Token: victor, Document Frequency: 1
# Token: video, Document Frequency: 4
# Token: videos, Document Frequency: 1
# Token: view, Document Frequency: 1
# Token: viewer, Document Frequency: 1
# Token: viewing, Document Frequency: 1
# Token: views, Document Frequency: 1
# Token: villain, Document Frequency: 1
# Token: vinaigrette, Document Frequency: 1
# Token: vinegrette, Document Frequency: 1
# Token: violin, Document Frequency: 1
# Token: violinists, Document Frequency: 1
# Token: virgin, Document Frequency: 1
# Token: virus, Document Frequency: 1
# Token: vision, Document Frequency: 1
# Token: visit, Document Frequency: 3
# Token: visited, Document Frequency: 1
# Token: visual, Document Frequency: 4
# Token: visually, Document Frequency: 2
# Token: vitally, Document Frequency: 1
# Token: vivian, Document Frequency: 1
# Token: vivid, Document Frequency: 1
# Token: vodka, Document Frequency: 1
# Token: voice, Document Frequency: 9
# Token: volatile, Document Frequency: 1
# Token: volcano, Document Frequency: 2
# Token: voltage, Document Frequency: 1
# Token: volume, Document Frequency: 8
# Token: vomit, Document Frequency: 1
# Token: vomited, Document Frequency: 2
# Token: voodoo, Document Frequency: 1
# Token: voyage, Document Frequency: 1
# Token: vulcan, Document Frequency: 1
# Token: vx, Document Frequency: 2
# Token: waaaaaayyyyyyyyyy, Document Frequency: 1
# Token: waaay, Document Frequency: 1
# Token: wagyu, Document Frequency: 1
# Token: wait, Document Frequency: 10
# Token: waited, Document Frequency: 9
# Token: waiter, Document Frequency: 7
# Token: waiting, Document Frequency: 6
# Token: waitress, Document Frequency: 7
# Token: walk, Document Frequency: 1
# Token: walked, Document Frequency: 6
# Token: walkman, Document Frequency: 1
# Token: wall, Document Frequency: 5
# Token: wallet, Document Frequency: 1
# Token: walls, Document Frequency: 1
# Token: want, Document Frequency: 19
# Token: wanted, Document Frequency: 9
# Token: wanting, Document Frequency: 1
# Token: wants, Document Frequency: 2
# Token: war, Document Frequency: 3
# Token: warm, Document Frequency: 6
# Token: warmer, Document Frequency: 1
# Token: warmth, Document Frequency: 2
# Token: warn, Document Frequency: 1
# Token: warning, Document Frequency: 3
# Token: warranty, Document Frequency: 2
# Token: was, Document Frequency: 448
# Token: wash, Document Frequency: 1
# Token: washing, Document Frequency: 1
# Token: wasn, Document Frequency: 19
# Token: waste, Document Frequency: 27
# Token: wasted, Document Frequency: 8
# Token: waster, Document Frequency: 1
# Token: wasting, Document Frequency: 2
# Token: watch, Document Frequency: 14
# Token: watchable, Document Frequency: 3
# Token: watched, Document Frequency: 9
# Token: watching, Document Frequency: 18
# Token: water, Document Frequency: 2
# Token: watered, Document Frequency: 1
# Token: waterproof, Document Frequency: 1
# Token: watkins, Document Frequency: 2
# Token: watson, Document Frequency: 2
# Token: wave, Document Frequency: 1
# Token: way, Document Frequency: 37
# Token: waylaid, Document Frequency: 1
# Token: wayne, Document Frequency: 2
# Token: ways, Document Frequency: 3
# Token: wayyy, Document Frequency: 1
# Token: wb, Document Frequency: 1
# Token: we, Document Frequency: 90
# Token: weak, Document Frequency: 6
# Token: weaker, Document Frequency: 1
# Token: wear, Document Frequency: 8
# Token: weariness, Document Frequency: 1
# Token: wearing, Document Frequency: 2
# Token: weaving, Document Frequency: 1
# Token: web, Document Frequency: 1
# Token: website, Document Frequency: 3
# Token: websites, Document Frequency: 1
# Token: wedding, Document Frequency: 1
# Token: week, Document Frequency: 6
# Token: weekend, Document Frequency: 1
# Token: weekly, Document Frequency: 1
# Token: weeks, Document Frequency: 3
# Token: weight, Document Frequency: 1
# Token: weird, Document Frequency: 4
# Token: welcome, Document Frequency: 1
# Token: well, Document Frequency: 74
# Token: went, Document Frequency: 18
# Token: were, Document Frequency: 92
# Token: weren, Document Frequency: 1
# Token: what, Document Frequency: 51
# Token: whatever, Document Frequency: 5
# Token: whatsoever, Document Frequency: 5
# Token: whelm, Document Frequency: 1
# Token: when, Document Frequency: 52
# Token: whenever, Document Frequency: 2
# Token: where, Document Frequency: 11
# Token: whether, Document Frequency: 6
# Token: which, Document Frequency: 46
# Token: while, Document Frequency: 22
# Token: whine, Document Frequency: 2
# Token: whiny, Document Frequency: 1
# Token: whistles, Document Frequency: 1
# Token: white, Document Frequency: 11
# Token: whites, Document Frequency: 1
# Token: who, Document Frequency: 44
# Token: whoa, Document Frequency: 1
# Token: whoever, Document Frequency: 1
# Token: whole, Document Frequency: 10
# Token: wholesome, Document Frequency: 2
# Token: whom, Document Frequency: 2
# Token: whose, Document Frequency: 1
# Token: why, Document Frequency: 10
# Token: wi, Document Frequency: 2
# Token: widmark, Document Frequency: 1
# Token: wienerschnitzel, Document Frequency: 1
# Token: wife, Document Frequency: 8
# Token: wih, Document Frequency: 1
# Token: wild, Document Frequency: 2
# Token: wildly, Document Frequency: 1
# Token: wilkinson, Document Frequency: 2
# Token: will, Document Frequency: 57
# Token: willie, Document Frequency: 1
# Token: wily, Document Frequency: 1
# Token: win, Document Frequency: 1
# Token: wind, Document Frequency: 4
# Token: window, Document Frequency: 1
# Token: windows, Document Frequency: 1
# Token: wine, Document Frequency: 3
# Token: wines, Document Frequency: 1
# Token: wings, Document Frequency: 3
# Token: winner, Document Frequency: 2
# Token: wiping, Document Frequency: 1
# Token: wire, Document Frequency: 1
# Token: wired, Document Frequency: 2
# Token: wirefly, Document Frequency: 1
# Token: wireless, Document Frequency: 2
# Token: wise, Document Frequency: 3
# Token: wish, Document Frequency: 4
# Token: wit, Document Frequency: 1
# Token: with, Document Frequency: 214
# Token: within, Document Frequency: 6
# Token: without, Document Frequency: 13
# Token: witnessed, Document Frequency: 1
# Token: witticisms, Document Frequency: 1
# Token: witty, Document Frequency: 2
# Token: woa, Document Frequency: 1
# Token: wobbly, Document Frequency: 1
# Token: women, Document Frequency: 2
# Token: won, Document Frequency: 21
# Token: wonder, Document Frequency: 3
# Token: wondered, Document Frequency: 1
# Token: wonderful, Document Frequency: 24
# Token: wonderfully, Document Frequency: 3
# Token: wont, Document Frequency: 2
# Token: wontons, Document Frequency: 1
# Token: woo, Document Frequency: 1
# Token: wood, Document Frequency: 1
# Token: wooden, Document Frequency: 2
# Token: word, Document Frequency: 8
# Token: words, Document Frequency: 4
# Token: work, Document Frequency: 43
# Token: worked, Document Frequency: 17
# Token: worker, Document Frequency: 1
# Token: workers, Document Frequency: 1
# Token: working, Document Frequency: 13
# Token: works, Document Frequency: 42
# Token: world, Document Frequency: 8
# Token: worn, Document Frequency: 1
# Token: worries, Document Frequency: 1
# Token: worry, Document Frequency: 1
# Token: worse, Document Frequency: 11
# Token: worst, Document Frequency: 29
# Token: worth, Document Frequency: 21
# Token: worthless, Document Frequency: 3
# Token: worthwhile, Document Frequency: 3
# Token: worthy, Document Frequency: 1
# Token: would, Document Frequency: 78
# Token: wouldn, Document Frequency: 6
# Token: wouldnt, Document Frequency: 1
# Token: wound, Document Frequency: 1
# Token: woven, Document Frequency: 1
# Token: wow, Document Frequency: 4
# Token: wrap, Document Frequency: 2
# Token: wrapped, Document Frequency: 1
# Token: write, Document Frequency: 1
# Token: writer, Document Frequency: 2
# Token: writers, Document Frequency: 1
# Token: writing, Document Frequency: 10
# Token: written, Document Frequency: 5
# Token: wrong, Document Frequency: 8
# Token: wrongly, Document Frequency: 1
# Token: wrote, Document Frequency: 1
# Token: ya, Document Frequency: 1
# Token: yama, Document Frequency: 1
# Token: yawn, Document Frequency: 1
# Token: yeah, Document Frequency: 3
# Token: year, Document Frequency: 13
# Token: years, Document Frequency: 20
# Token: yell, Document Frequency: 1
# Token: yellow, Document Frequency: 1
# Token: yellowtail, Document Frequency: 1
# Token: yelpers, Document Frequency: 1
# Token: yes, Document Frequency: 2
# Token: yet, Document Frequency: 8
# Token: you, Document Frequency: 177
# Token: young, Document Frequency: 3
# Token: younger, Document Frequency: 1
# Token: your, Document Frequency: 66
# Token: yourself, Document Frequency: 3
# Token: youthful, Document Frequency: 1
# Token: youtube, Document Frequency: 1
# Token: yucky, Document Frequency: 1
# Token: yukon, Document Frequency: 1
# Token: yum, Document Frequency: 2
# Token: yummy, Document Frequency: 3
# Token: yun, Document Frequency: 1
# Token: za, Document Frequency: 1
# Token: zero, Document Frequency: 6
# Token: zillion, Document Frequency: 1
# Token: zombie, Document Frequency: 1

# %% [markdown]
# ### Perform Grid Search

# %%
# Create a pipeline for text classification
my_bow_classifier_pipeline = sklearn.pipeline.Pipeline([
    ('my_bow_feature_extractor', CountVectorizer(preprocessor=combined_preprocessor, min_df=1, max_df=0.09, ngram_range=(1, 1))),
    ('my_classifier', sklearn.linear_model.LogisticRegression(C=1.0, max_iter=1000, random_state=1)),
])

# Define a parameter grid for hyperparameter tuning
my_parameter_grid_by_name = dict()
my_parameter_grid_by_name['my_bow_feature_extractor__min_df'] = [5, 10, 15, 20, 80, 140, 160]
my_parameter_grid_by_name['my_bow_feature_extractor__max_df'] = [0.1, 0.2, 0.4, 0.8, 1.0]
my_parameter_grid_by_name['my_classifier__C'] = np.logspace(-4, 4, 9)

# Choose a scoring metric for model evaluation
my_scoring_metric_name = 'roc_auc'

# Create a KFold object for cross-validation with 10 folds
k_fold = sklearn.model_selection.KFold(n_splits=5, shuffle=True, random_state=0)

# Use GridSearchCV for hyperparameter tuning with cross-validation
grid_searcher = sklearn.model_selection.GridSearchCV(
    my_bow_classifier_pipeline,  # The model pipeline
    my_parameter_grid_by_name,  # The parameter grid to search
    scoring=my_scoring_metric_name,  # The evaluation metric
    cv=k_fold,  # 10-fold cross-validation
    refit=True,  # Refit the best model
    return_train_score=True # Receive training scores

)

# Shuffle the data before feeding it into the model
rand_text_col_arr, rand_results_col_arr = shuffle(text_col_arr, results_col_arr, random_state=1)

# Fit the grid search to find the best model and hyperparameters
grid_searcher.fit(rand_text_col_arr, rand_results_col_arr)
# Out:
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\31618\envs\cs135_env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#              estimator=Pipeline(steps=[('my_bow_feature_extractor',
#                                         CountVectorizer(max_df=0.09,
#                                                         preprocessor=<function combined_preprocessor at 0x000001418BEB0430>)),
#                                        ('my_classifier',
#                                         LogisticRegression(max_iter=1000,
#                                                            random_state=1))]),
#              param_grid={'my_bow_feature_extractor__max_df': [0.1, 0.2, 0.4,
#                                                               0.8, 1.0],
#                          'my_bow_feature_extractor__min_df': [5, 10, 15, 20, 80,
#                                                               140, 160],
#                          'my_classifier__C': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])},
#              return_train_score=True, scoring='roc_auc')

# %%
cv_results_df = pd.DataFrame(grid_searcher.cv_results_)
print(cv_results_df)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.076989      0.011814         0.021265        0.006486
# 1         0.070233      0.005300         0.017756        0.001579
# 2         0.065592      0.001903         0.019721        0.003011
# 3         0.091815      0.013602         0.019488        0.006067
# 4         0.091852      0.010173         0.017406        0.001370
# ..             ...           ...              ...             ...
# 310       0.070480      0.010422         0.015992        0.001526
# 311       0.065080      0.000772         0.016323        0.001825
# 312       0.069016      0.005097         0.020568        0.010383
# 313       0.068743      0.007709         0.017797        0.004719
# 314       0.075243      0.011977         0.018278        0.004724
#
#     param_my_bow_feature_extractor__max_df  \
# 0                                      0.1
# 1                                      0.1
# 2                                      0.1
# 3                                      0.1
# 4                                      0.1
# ..                                     ...
# 310                                    1.0
# 311                                    1.0
# 312                                    1.0
# 313                                    1.0
# 314                                    1.0
#
#     param_my_bow_feature_extractor__min_df param_my_classifier__C  \
# 0                                        5                 0.0001
# 1                                        5                  0.001
# 2                                        5                   0.01
# 3                                        5                    0.1
# 4                                        5                    1.0
# ..                                     ...                    ...
# 310                                    160                    1.0
# 311                                    160                   10.0
# 312                                    160                  100.0
# 313                                    160                 1000.0
# 314                                    160                10000.0
#
#                                                 params  split0_test_score  \
# 0    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.817716
# 1    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.820564
# 2    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.839340
# 3    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.874581
# 4    {'my_bow_feature_extractor__max_df': 0.1, 'my_...           0.881198
# ..                                                 ...                ...
# 310  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621937
# 311  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
# 312  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
# 313  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
# 314  {'my_bow_feature_extractor__max_df': 1.0, 'my_...           0.621902
#
#      split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0             0.751685  ...         0.796887        0.030160               73
# 1             0.752103  ...         0.799176        0.030493               64
# 2             0.757936  ...         0.815287        0.032121               31
# 3             0.785830  ...         0.848177        0.032584                6
# 4             0.811043  ...         0.860191        0.027438                1
# ..                 ...  ...              ...             ...              ...
# 310           0.587305  ...         0.631236        0.028307              250
# 311           0.587932  ...         0.631205        0.028061              258
# 312           0.587827  ...         0.631215        0.028112              252
# 313           0.587827  ...         0.631208        0.028104              254
# 314           0.587827  ...         0.631208        0.028104              254
#
#      split0_train_score  split1_train_score  split2_train_score  \
# 0              0.844372            0.857139            0.847453
# 1              0.847366            0.860249            0.850709
# 2              0.868903            0.881039            0.872750
# 3              0.920649            0.929119            0.925703
# 4              0.961274            0.964100            0.965631
# ..                  ...                 ...                 ...
# 310            0.645321            0.655272            0.636506
# 311            0.645109            0.655107            0.636331
# 312            0.645084            0.654944            0.636308
# 313            0.645226            0.654948            0.636311
# 314            0.645225            0.654948            0.636309
#
#      split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0              0.836946            0.839856          0.845153         0.007000
# 1              0.840244            0.843692          0.848452         0.006863
# 2              0.864455            0.868457          0.871121         0.005612
# 3              0.919536            0.919989          0.922999         0.003778
# 4              0.961456            0.960555          0.962603         0.001933
# ..                  ...                 ...               ...              ...
# 310            0.642249            0.642140          0.644298         0.006181
# 311            0.642438            0.642207          0.644238         0.006145
# 312            0.642446            0.642225          0.644201         0.006091
# 313            0.642441            0.642225          0.644230         0.006096
# 314            0.642441            0.642227          0.644230         0.006096
#
# [315 rows x 23 columns]

# %% [markdown]
# ### HyperParameter Selection for Logistic Regression Classifier

# %%
# Extract the relevant data for 'my_classifier__C' hyperparameter
hyperparameter_values = grid_searcher.cv_results_['param_my_classifier__C']
mean_train_scores = grid_searcher.cv_results_['mean_train_score']
mean_test_scores = grid_searcher.cv_results_['mean_test_score']

# Save raw hyperparameter values
hyperparameter_values_str = hyperparameter_values.astype(str)

# Create a DataFrame for hyperparameter vs AUROC
df = pd.DataFrame({'C Value': hyperparameter_values_str,
                   'Train AUROC': mean_train_scores,
                   'Validation AUROC': mean_test_scores})

# Use Seaborn to create line plots
plt.figure(figsize=(10, 6))
ax = sns.lineplot(x='C Value', y='Train AUROC', data=df, label='Training AUROC')
ax = sns.lineplot(x='C Value', y='Validation AUROC', data=df, label='Validation AUROC')

# Label the axes, title, and legend
plt.xlabel('C Value')
plt.ylabel('AUROC')
plt.title("Average ROC on Training and Validation Sets vs. C Values")
plt.legend()
plt.show()

# %% [markdown]
# ### Analysis of Predictions for the Best Classifier

# %%
import random

# Print best parameters
print('Best Parameters:', grid_searcher.best_params_)


# Prepare the the test data
our_test_x_arr =  our_test_x_df['text'].values
our_test_y_arr = np.ravel(our_test_y_df.values)

# Preprocess the x values
our_reprocessor = my_bow_classifier_pipeline.named_steps['my_bow_feature_extractor'].build_preprocessor()
our_preprocessed_test = [our_reprocessor(doc) for doc in our_test_x_arr]

# Predict the y values
best_model = grid_searcher.best_estimator_
model_test_y_arr = best_model.predict_proba(our_preprocessed_test)[:,1]


# Define a threshold for classification
threshold = 0.5

# Classify predictions using the threshold
predicted_labels = (model_test_y_arr > threshold).astype(int)

# Find the indices of false positives and false negatives
false_positive_indices = np.where((predicted_labels == 1) & (our_test_y_arr == 0))[0]
false_negative_indices = np.where((predicted_labels == 0) & (our_test_y_arr == 1))[0]

# Create lists of false positives and false negatives
false_positives = [our_test_x_arr[i] for i in false_positive_indices]
false_negatives = [our_test_x_arr[i] for i in false_negative_indices]


# Randomly sample a subset of false positives and false negatives
num_samples = 5  # Adjust this number as needed
selected_false_positives = random.sample(false_positives, num_samples)
selected_false_negatives = random.sample(false_negatives, num_samples)

# Visualize the examples in a figure
plt.figure(figsize=(12, 6))

for i, example in enumerate(selected_false_positives):
    plt.subplot(2, num_samples, i + 1)
    plt.text(0.5, 0.5, i + 1, fontsize=12, ha='center')
    plt.title('False Positive')

for i, example in enumerate(selected_false_negatives):
    plt.subplot(2, num_samples, num_samples + i + 1)
    plt.text(0.5, 0.5, i + 6, fontsize=12, ha='center')
    plt.title('False Negative')


plt.tight_layout()

analysis_text = 'Reviews: \n'

for i, example in enumerate(selected_false_positives):
    analysis_text += str(i + 1) +  '. ' + example + '\n'


for i, example in enumerate(selected_false_negatives):
    analysis_text += str(i + 6) +  '. ' + example + '\n'

plt.figtext(0.1, -0.4, analysis_text, fontsize=12)


# Analysis paragraph
# plt.figtext(0.1, -0.1, "Analysis: \n\n1. Sentence Length: \n2. Review Types: \n3. Negation Words:", fontsize=12)

plt.show()

# # Produce the ROC Curve
# fpr, tpr, thresholds= sklearn.metrics.roc_curve(our_test_y_arr, model_test_y_arr)
#
#
# plt.plot(fpr, tpr, color ='b', lw=2, label='Best Model', linestyle='-.');
#
# plt.title("ROC on Test Set");
# plt.xlabel('false positive rate');
# plt.ylabel('true positive rate');
# plt.legend(loc='lower right');
# B = 0.01
# plt.xlim([0 - B, 1 + B]);
# plt.ylim([0 - B, 1 + B]);
# Out:
# Best Parameters: {'my_bow_feature_extractor__max_df': 0.1, 'my_bow_feature_extractor__min_df': 5, 'my_classifier__C': 1.0}

# %% [markdown]
# ### Performance on Test Set via Leaderboard

# %%
# Retrieve the preprocessor
preprocessor = my_bow_classifier_pipeline.named_steps['my_bow_feature_extractor'].build_preprocessor()

# Use preprocessor on test data (for all lower tokens, no numbers, no punctuation)
test_text_col_arr = x_test_df['text'].values
preprocessed_test_data = [preprocessor(doc) for doc in test_text_col_arr]

# Use best model to make probabilistic predictions
best_model = grid_searcher.best_estimator_
test_prob_predictions = best_model.predict_proba(preprocessed_test_data)

# Get the probabilities for positive prediction
positive_prob = test_prob_predictions[:, 1]
print(positive_prob)


# Define the file path where you want to save the CSV file
file_path = 'yproba1_test.txt'

# Save the 'positive_prob' array as a CSV file
np.savetxt(file_path, positive_prob, delimiter=',', fmt='%s')
# Out:
# [4.98411211e-01 3.92240899e-01 2.47675845e-01 7.00495030e-02
#  2.66025166e-01 6.67617453e-02 5.85981844e-02 1.11592264e-01
#  1.36882682e-01 6.26727064e-01 4.44544220e-01 8.00194385e-01
#  5.42212838e-02 1.38223952e-01 1.68551856e-01 8.06572431e-02
#  2.68061679e-03 1.31675966e-01 3.79302584e-01 5.43536653e-01
#  3.58049930e-01 4.74602676e-01 3.22009719e-01 3.36663720e-01
#  4.52096793e-01 4.22818357e-01 2.40780166e-01 4.52501788e-01
#  2.13926908e-01 2.75661143e-01 6.05830555e-01 3.48859038e-01
#  2.54208944e-01 1.00992673e-02 2.80028969e-01 3.04821275e-01
#  3.84305885e-01 1.58815896e-01 4.38360229e-01 3.52386637e-01
#  7.63632087e-02 2.13926908e-01 4.49497985e-01 2.60960369e-01
#  1.83458937e-01 9.07905260e-02 2.55500926e-01 7.56998455e-02
#  9.42127724e-03 2.13926908e-01 1.29815711e-01 1.52042234e-01
#  8.57827830e-01 4.61159633e-01 3.93217229e-01 2.31984364e-01
#  1.43814774e-01 8.63210441e-02 6.15701905e-01 7.24098334e-02
#  3.82066802e-01 1.16625279e-01 1.24255469e-01 7.28852636e-02
#  1.01143506e-01 5.18033885e-02 4.11749699e-02 4.71400042e-01
#  1.08717332e-01 5.76365906e-01 7.96241173e-02 4.52501788e-01
#  1.18770861e-01 1.54248886e-02 2.98610354e-01 4.17271891e-01
#  4.13315834e-01 3.02445437e-02 5.85682984e-01 8.34773554e-02
#  1.80600661e-01 1.07424421e-02 2.18140465e-01 3.34220043e-01
#  5.71254582e-03 3.96372184e-01 1.30392447e-01 8.45042735e-02
#  2.64317260e-01 5.43816879e-02 3.71876108e-01 2.79114965e-01
#  5.14764175e-01 7.81369024e-02 2.59294896e-01 3.33355088e-01
#  2.95184511e-01 3.16716744e-01 9.54965137e-02 3.83128768e-01
#  9.92067464e-01 5.75521792e-01 5.73697694e-01 9.37215460e-01
#  5.97929098e-01 9.74012310e-01 9.10727763e-01 9.64310650e-01
#  5.13470731e-04 8.07327720e-02 9.13871529e-01 4.03337325e-01
#  9.26137637e-01 2.68207422e-01 8.08542008e-01 7.09838232e-01
#  8.02638172e-01 9.36533523e-01 8.02276365e-01 4.52501788e-01
#  6.42053476e-02 7.52674700e-01 8.17380714e-01 9.38515570e-01
#  9.27050957e-01 9.67276821e-01 8.19795114e-01 8.01624374e-01
#  9.80022533e-01 5.50264277e-01 9.97936325e-01 8.00396209e-01
#  9.68078816e-01 9.90999649e-01 9.96974100e-01 4.79384716e-01
#  5.13722416e-02 9.25968923e-01 8.36446372e-01 9.61160886e-01
#  9.41420177e-01 7.39899931e-02 8.73825126e-01 9.35546532e-01
#  8.29301848e-01 7.93157455e-01 8.23682013e-02 2.11118493e-01
#  9.72533882e-01 9.34932352e-01 9.99896165e-01 9.32693520e-01
#  7.52711273e-01 9.12529595e-01 6.23221329e-01 6.68734824e-01
#  7.59324012e-01 5.43183408e-01 9.22643905e-01 5.15450586e-01
#  5.44373306e-01 4.71723370e-01 6.70714688e-01 9.62234205e-01
#  9.36315828e-01 3.13492917e-01 8.44261337e-01 4.61886945e-01
#  4.57296503e-01 4.93286546e-01 4.87394263e-01 4.44191151e-01
#  4.52501788e-01 6.92290166e-01 8.74008468e-01 9.93380745e-01
#  4.91449791e-01 4.48420740e-01 9.79329583e-01 6.40151427e-01
#  8.46960984e-01 8.69379982e-02 6.07747646e-01 8.90224320e-01
#  6.24018952e-01 9.37457417e-01 8.85044260e-01 9.54552720e-01
#  4.52959810e-01 9.02580812e-01 9.39872550e-01 7.05827619e-01
#  5.56914748e-01 9.86696286e-01 8.43128600e-01 8.11836319e-01
#  4.98277653e-01 5.77699762e-01 4.08176600e-01 9.15717326e-01
#  9.34391798e-02 3.23666266e-01 2.15135963e-01 6.51390948e-01
#  9.67261291e-03 3.28922053e-01 5.83846772e-02 9.72844858e-04
#  2.87751159e-01 6.68066490e-01 1.28242720e-01 2.79299171e-01
#  3.88109677e-01 2.74992809e-01 5.25652888e-01 3.97683346e-01
#  2.48074727e-01 3.63778320e-01 3.33077623e-01 7.16347961e-02
#  2.88627846e-02 1.44542378e-01 3.73034788e-01 5.45657836e-01
#  3.19375626e-02 2.43762433e-02 1.11238802e-01 4.69701283e-01
#  2.63880302e-01 3.87846200e-01 2.97716453e-02 9.25566887e-02
#  8.46859665e-01 4.29156419e-01 5.40001550e-01 1.46587824e-01
#  6.43711453e-02 5.72723107e-01 5.92168208e-01 3.45221161e-02
#  1.18703488e-01 5.61433650e-02 5.16266064e-01 2.03596843e-03
#  8.65774343e-01 2.52550751e-02 1.58967758e-01 3.87322224e-04
#  9.38008285e-02 5.10675340e-01 5.12219484e-01 8.45281511e-01
#  7.52813466e-01 5.38571776e-02 6.23319870e-01 2.16138116e-01
#  4.65782499e-01 1.29301368e-01 1.30857730e-01 2.42993516e-01
#  3.70523814e-01 1.33835409e-01 1.70215216e-01 7.66636528e-02
#  1.46450040e-01 2.64339662e-01 2.53326088e-01 1.54275041e-01
#  3.32409644e-02 1.43039348e-01 5.72372687e-02 8.32864190e-02
#  3.63300126e-01 7.19531478e-01 3.20626964e-01 3.08087388e-01
#  4.05329395e-01 2.11510616e-01 4.75308092e-01 1.87304630e-01
#  2.31526299e-01 4.34874758e-01 7.19140351e-01 2.91606184e-01
#  8.47660647e-02 5.74727643e-02 5.75191326e-01 1.43712500e-01
#  2.07290704e-01 7.78369616e-01 2.20595721e-01 4.34874758e-01
#  4.42530807e-02 7.10062761e-03 2.98433554e-01 1.26277062e-02
#  6.68629569e-01 4.34874758e-01 6.95569850e-02 6.33619682e-01
#  7.16380614e-01 4.54930584e-01 8.49050400e-01 8.72188722e-01
#  6.24893979e-01 9.80343704e-01 6.60846799e-01 3.38784452e-01
#  2.80711077e-01 4.54856479e-01 7.12387002e-01 4.52501788e-01
#  5.62207520e-01 2.99436595e-01 4.69245070e-01 7.90096404e-01
#  1.22684061e-01 9.17890436e-01 5.27306961e-01 8.27432439e-01
#  9.27738502e-01 9.99648143e-01 8.03557585e-01 5.15236757e-01
#  6.61026063e-01 8.47767311e-01 9.99774803e-01 4.83921544e-01
#  9.41850711e-01 4.86410653e-01 9.93661349e-01 6.96199729e-01
#  5.66044815e-01 1.73693913e-01 5.05794078e-01 9.06079684e-01
#  8.81828977e-01 9.27367467e-01 6.36439802e-01 4.44843309e-01
#  3.84611988e-01 1.18330833e-01 1.82540379e-01 4.60534054e-01
#  9.40276497e-01 7.98362472e-01 6.37012516e-01 7.75251005e-01
#  1.69241437e-01 7.10833211e-01 6.02820401e-01 1.29427933e-01
#  8.18690386e-01 7.95525352e-01 8.61501155e-01 4.33262617e-01
#  9.26092808e-01 8.45899219e-01 9.71417650e-01 9.44911229e-01
#  3.65439771e-01 9.19776933e-01 3.99955832e-01 2.99868707e-01
#  8.08290652e-01 5.88951376e-01 9.03975485e-01 9.46741836e-01
#  5.17589224e-01 7.36166687e-01 1.58505058e-01 8.11875758e-01
#  6.19692657e-01 9.01053538e-01 5.46244749e-01 7.45164024e-01
#  8.75732865e-01 6.58184032e-01 6.68717968e-01 7.76770199e-01
#  3.77596961e-01 8.79313226e-01 4.04156145e-01 9.86883799e-01
#  6.77806383e-01 5.65515964e-01 5.73375457e-01 3.16176364e-01
#  8.75819266e-01 8.00937940e-01 4.93982120e-01 2.46391456e-01
#  9.55037283e-01 7.34605363e-03 6.59719084e-02 9.80531558e-01
#  2.78260017e-01 7.12357382e-01 1.27387132e-01 8.09022252e-01
#  9.21450401e-02 1.80347367e-01 7.11130854e-03 3.82834344e-01
#  3.86312877e-01 1.77411461e-01 1.04887994e-01 4.71929710e-02
#  1.33938893e-01 5.48676467e-01 3.93139846e-01 6.58237607e-02
#  1.30319406e-01 2.86106423e-01 2.13066891e-01 1.28330562e-01
#  4.64952091e-01 1.85037856e-01 3.53347211e-01 3.16154487e-01
#  3.06587418e-01 3.02805125e-01 3.79884690e-01 2.33370262e-02
#  5.30984828e-01 5.36986406e-01 5.03738613e-01 4.08486036e-01
#  6.65746198e-01 4.16129581e-01 9.06604960e-02 3.72007112e-01
#  2.09082141e-02 2.65690482e-01 1.74817239e-01 3.82450176e-01
#  5.92168208e-01 9.30415452e-02 6.13202350e-02 3.15480718e-01
#  9.76750098e-01 3.63251262e-01 7.11836546e-02 1.37772052e-01
#  1.04521560e-01 9.02691048e-02 5.92263331e-01 2.07769506e-02
#  7.16708171e-01 5.49759139e-01 2.81687315e-01 2.61532080e-01
#  2.89508545e-01 5.21114660e-01 1.81943061e-01 6.16795470e-01
#  5.71985664e-01 5.18935695e-01 5.07368115e-01 2.40912269e-01
#  1.08970883e-01 1.30186261e-01 4.95730754e-01 4.57215070e-01
#  3.54830533e-01 3.77560268e-01 2.83765592e-01 4.42019918e-01
#  4.13605664e-01 8.01848531e-01 5.40472510e-01 4.32308097e-01
#  4.61393392e-01 1.01244669e-01 2.86192827e-01 6.12295334e-01
#  2.72227013e-01 3.65066257e-01 1.33887317e-01 3.29046413e-01
#  1.45771122e-02 4.31685430e-01 1.18785883e-01 1.47426479e-01
#  4.20525815e-01 1.88823502e-01 4.55131113e-03 5.07649385e-01
#  5.30781806e-01 1.02245862e-01 1.61675131e-01 4.87831302e-01
#  2.14188958e-01 4.71400042e-01 3.89602938e-01 3.12161030e-01
#  6.29306980e-02 1.36670431e-01 2.99069791e-01 3.30275790e-01
#  9.87228113e-01 8.24991275e-01 8.29026755e-01 1.24390420e-01
#  6.88558291e-01 6.93514394e-01 9.49403159e-01 9.28905743e-01
#  9.67686062e-01 3.47496678e-01 5.12095508e-01 9.09745159e-01
#  6.68727512e-01 6.02118100e-01 6.16875929e-01 9.05614683e-01
#  8.80471358e-01 9.07325446e-01 7.39717243e-01 8.58464278e-01
#  7.70384527e-01 8.01624374e-01 7.38232827e-01 1.04427986e-01
#  5.76830800e-01 9.48808110e-01 1.50119177e-01 7.49261812e-01
#  6.74961943e-01 9.98680112e-01 5.06135813e-01 9.36533523e-01
#  4.18153729e-01 9.66980321e-01 5.42539606e-01 3.79336325e-01
#  5.55553341e-01 4.06979755e-01 8.64633362e-01 9.68655415e-01
#  5.31088107e-01 5.05746800e-01 9.60028198e-01 8.34984896e-01
#  8.08231529e-01 7.67303021e-01 9.66872122e-01 6.19752701e-01
#  9.79178804e-01 9.99215742e-01 5.54536108e-01 2.59342992e-02
#  6.59936285e-01 9.27367414e-01 9.28239735e-01 9.59954309e-01
#  6.22023211e-01 8.28067421e-01 4.88047647e-01 4.82205385e-01
#  6.98328442e-01 8.63451790e-01 9.94106577e-01 9.40657779e-01
#  3.75516495e-01 2.56035508e-01 2.91320080e-01 9.15210062e-01
#  8.47673551e-01 4.71284591e-01 9.39449653e-01 7.23551776e-01
#  4.00180005e-01 3.89549973e-01 6.71880422e-01 2.88907554e-01
#  6.94592858e-01 8.64368756e-01 8.26219539e-01 7.85933953e-01
#  9.09467929e-01 3.26745217e-01 9.06708944e-01 5.20040182e-01
#  8.21012871e-01 9.19437213e-01 8.24639969e-01 8.85778615e-01
#  9.31446561e-01 4.62056937e-01 2.15690833e-01 3.07826176e-01
#  8.05731629e-01 3.76769362e-01 8.64997675e-01 9.66504808e-01
#  8.31559866e-01 8.75255572e-01 9.97547491e-01 8.19795114e-01]
